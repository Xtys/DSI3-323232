# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def mean_calculation(numbers):
    sum_of_numbers = 0
    for i in numbers:
        sum_of_numbers+=i
    mean = sum_of_numbers/len(numbers)
    return mean

# %%
mean_calculation ([2,4,6,8,10])
# Out:
# 6.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def std_dev(numbers):
    sum_of_squares = 0
    for i in numbers:
        sum_of_squares+=(i-mean_calculation(numbers))**2
    standard_deviation = (sum_of_squares/len(numbers))**0.5
    return standard_deviation

# %%
print(std_dev([2,4,6,8,10]))
# Out:
# 2.8284271247461903

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def clean_data(string):
    return float(string.split('%')[0])/100

# %%
clean_data('69.5%')
# Out:
# 0.695

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import scipy as sp
# plotting: 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ### SAT Data 2017 to 2019

# %%
#Importing datasets
# 2017 SAT Scores
sat_2017 = pd.read_csv('../data/sat_2017.csv')
# 2018 SAT Scores
sat_2018 = pd.read_csv('../data/sat_2018.csv')
# 2019 SAT Scores
sat_2019 = pd.read_csv('../data/sat_2019.csv')

# %%
print(sat_2017.shape)
sat_2017.head()
# Out:
# (51, 5)
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
#Participation should be a float 2017
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
print(sat_2018.shape)
sat_2018.head()
# Out:
# (51, 5)
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
#Participation should be a float 2018
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
print(sat_2019.shape) 
sat_2019.head()
# Out:
# (53, 5)
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
#Participation should be a float 2019
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
#reaname some columns 
sat_2017 = sat_2017.rename(columns={'State':'state','Participation': '2017_participation', 'Evidence-Based Reading and Writing': 'ebrw_2017', 'Math':'math_2017','Total':'total_2017'})
sat_2018 = sat_2018.rename(columns={'State':'state','Participation': '2018_participation', 'Evidence-Based Reading and Writing': 'ebrw_2018','Math':'math_2018','Total':'total_2018'})
sat_2019 = sat_2019.rename(columns={'State':'state','Participation Rate': '2019_participation', 'EBRW': 'ebrw_2019','Math':'math_2019','Total':'total_2019'})

# %%
# Clean Participation column 2017 to 2019:
sat_2017['2017_participation'] = sat_2017['2017_participation'].apply(clean_data)
sat_2017.head()
# Out:
#         state  2017_participation  ebrw_2017  math_2017  total_2017
# 0     Alabama                0.05        593        572        1165
# 1      Alaska                0.38        547        533        1080
# 2     Arizona                0.30        563        553        1116
# 3    Arkansas                0.03        614        594        1208
# 4  California                0.53        531        524        1055

# %%
sat_2018['2018_participation'] = sat_2018['2018_participation'].apply(clean_data)
sat_2018.head()
# Out:
#         state  2018_participation  ebrw_2018  math_2018  total_2018
# 0     Alabama                0.06        595        571        1166
# 1      Alaska                0.43        562        544        1106
# 2     Arizona                0.29        577        572        1149
# 3    Arkansas                0.05        592        576        1169
# 4  California                0.60        540        536        1076

# %%
#Checking, as there is unknown symbol need to be clean(39 and 47)
sat_2019['2019_participation'].unique
# Out:
# <bound method Series.unique of 0       7%
# 1      41%
# 2      31%
# 3       6%
# 4      63%
# 5     100%
# 6     100%
# 7     100%
# 8      94%
# 9     100%
# 10     71%
# 11     54%
# 12    100%
# 13    100%
# 14     66%
# 15      3%
# 16      4%
# 17      4%
# 18      5%
# 19     99%
# 20     82%
# 21     81%
# 22    100%
# 23      4%
# 24      3%
# 25      4%
# 26      9%
# 27      3%
# 28     20%
# 29     95%
# 30     82%
# 31     18%
# 32     79%
# 33     51%
# 34      2%
# 35     19%
# 36     22%
# 37     51%
# 38     70%
# 39       —
# 40    100%
# 41     68%
# 42      3%
# 43      7%
# 44     68%
# 45      4%
# 46     66%
# 47       —
# 48     68%
# 49     70%
# 50     99%
# 51      3%
# 52      3%
# Name: 2019_participation, dtype: object>

# %%
#see any null
sat_2019.isnull().sum()
# Out:
# state                 0
# 2019_participation    0
# ebrw_2019             0
# math_2019             0
# total_2019            0
# dtype: int64

# %%
sat_2019.describe()
# Out:
#         ebrw_2019   math_2019   total_2019
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %%
#converting to NaN , as we need to change symbol
sat_2019[sat_2019['2019_participation'].str.contains('—')]
# Out:
#              state 2019_participation  ebrw_2019  math_2019  total_2019
# 39     Puerto Rico                  —        483        462         944
# 47  Virgin Islands                  —        490        445         935

# %%
sat_2019['2019_participation'].replace('—', '0%', inplace=True)

# %%
#two states are not of USA 
sat_2019.iloc[[39,47]]
# Out:
#              state 2019_participation  ebrw_2019  math_2019  total_2019
# 39     Puerto Rico                 0%        483        462         944
# 47  Virgin Islands                 0%        490        445         935

# %%
#apply the convert
sat_2019['2019_participation'] = sat_2019['2019_participation'].apply(clean_data)
sat_2019.head()
# Out:
#         state  2019_participation  ebrw_2019  math_2019  total_2019
# 0     Alabama                0.07        583        560        1143
# 1      Alaska                0.41        556        541        1097
# 2     Arizona                0.31        569        565        1134
# 3    Arkansas                0.06        582        559        1141
# 4  California                0.63        534        531        1065

# %%
#merging : 2017 to 2019
sat_2017to2019 = pd.merge(left=pd.merge(left=sat_2017, right= sat_2018, how='right', on= 'state'),
                          right=sat_2019, how='right', on='state')
sat_2017to2019
# Out:
#                    state  2017_participation  ebrw_2017  math_2017  \
# 0                Alabama                0.05      593.0      572.0
# 1                 Alaska                0.38      547.0      533.0
# 2                Arizona                0.30      563.0      553.0
# 3               Arkansas                0.03      614.0      594.0
# 4             California                0.53      531.0      524.0
# 5               Colorado                0.11      606.0      595.0
# 6            Connecticut                1.00      530.0      512.0
# 7               Delaware                1.00      503.0      492.0
# 8   District of Columbia                1.00      482.0      468.0
# 9                Florida                0.83      520.0      497.0
# 10               Georgia                0.61      535.0      515.0
# 11                Hawaii                0.55      544.0      541.0
# 12                 Idaho                0.93      513.0      493.0
# ...

# %%
#gonna drop these two not USA (39 and 47)
sat_2017to2019[sat_2017to2019['2017_participation'].isnull()==True]
# Out:
#              state  2017_participation  ebrw_2017  math_2017  total_2017  \
# 39     Puerto Rico                 NaN        NaN        NaN         NaN
# 47  Virgin Islands                 NaN        NaN        NaN         NaN
#
#     2018_participation  ebrw_2018  math_2018  total_2018  2019_participation  \
# 39                 NaN        NaN        NaN         NaN                 0.0
# 47                 NaN        NaN        NaN         NaN                 0.0
#
#     ebrw_2019  math_2019  total_2019
# 39        483        462         944
# 47        490        445         935

# %%
sat_2017to2019.shape
# Out:
# (53, 13)

# %%
sat_2017to2019.drop(index=[39,47],inplace=True)

# %%
sat_2017to2019.reset_index(drop=True, inplace=True)

# %%
#Now merged 2017 to 2019 data is cleaned
print(sat_2017to2019.shape)
print(sat_2017to2019.info())
sat_2017to2019
# Out:
# (51, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               51 non-null     object
#  1   2017_participation  51 non-null     float64
#  2   ebrw_2017           51 non-null     float64
#  3   math_2017           51 non-null     float64
#  4   total_2017          51 non-null     float64
#  5   2018_participation  51 non-null     float64
#  6   ebrw_2018           51 non-null     float64
#  7   math_2018           51 non-null     float64
#  8   total_2018          51 non-null     float64
#  9   2019_participation  51 non-null     float64
#  10  ebrw_2019           51 non-null     int64
#  11  math_2019           51 non-null     int64
#  12  total_2019          51 non-null     int64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 5.3+ KB
# None
# ...

# %% [markdown]
# ### SAT Data California 2019

# %%
#Importing datasets
#2019 Californian SAT Scores
sat_2019c = pd.read_csv('../data/sat_2019_ca.csv')

# %%
sat_2019c.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# ...

# %%
sat_2019c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    2579 non-null   float64
#  1   CCode                  2579 non-null   float64
#  2   CDCode                 2579 non-null   float64
#  3   SCode                  2579 non-null   float64
#  4   RType                  2579 non-null   object
#  5   SName                  1982 non-null   object
#  6   DName                  2521 non-null   object
#  7   CName                  2579 non-null   object
#  8   Enroll12               2579 non-null   float64
#  9   NumTSTTakr12           2579 non-null   float64
#  10  NumERWBenchmark12      2304 non-null   object
#  11  PctERWBenchmark12      2304 non-null   object
#  12  NumMathBenchmark12     2304 non-null   object
#  13  PctMathBenchmark12     2304 non-null   object
# ...

# %%
#convert all lower caps
sat_2019c.columns = sat_2019c.columns.str.lower()

# %%
sat_2019c.columns
# Out:
# Index(['cds', 'ccode', 'cdcode', 'scode', 'rtype', 'sname', 'dname', 'cname',
#        'enroll12', 'numtsttakr12', 'numerwbenchmark12', 'pcterwbenchmark12',
#        'nummathbenchmark12', 'pctmathbenchmark12', 'enroll11', 'numtsttakr11',
#        'numerwbenchmark11', 'pcterwbenchmark11', 'nummathbenchmark11',
#        'pctmathbenchmark11', 'totnumbothbenchmark12', 'pctbothbenchmark12',
#        'totnumbothbenchmark11', 'pctbothbenchmark11', 'year', 'unnamed: 25'],
#       dtype='object')

# %%
#changing to line with our problem statement, county of cali
sat_2019ca_count = sat_2019c[sat_2019c.rtype=='C']
sat_2019ca_count.reset_index(drop= True, inplace = True)
print(sat_2019ca_count.info())
sat_2019ca_count.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cds                    58 non-null     float64
#  1   ccode                  58 non-null     float64
#  2   cdcode                 58 non-null     float64
#  3   scode                  58 non-null     float64
#  4   rtype                  58 non-null     object
#  5   sname                  0 non-null      object
#  6   dname                  0 non-null      object
#  7   cname                  58 non-null     object
#  8   enroll12               58 non-null     float64
#  9   numtsttakr12           58 non-null     float64
#  10  numerwbenchmark12      57 non-null     object
#  11  pcterwbenchmark12      57 non-null     object
#  12  nummathbenchmark12     57 non-null     object
#  13  pctmathbenchmark12     57 non-null     object
# ...

# %%
#checking null
sat_2019c.isnull().values.any()
# Out:
# True

# %%
sat_2019c.isnull().sum()
# Out:
# cds                         1
# ccode                       1
# cdcode                      1
# scode                       1
# rtype                       1
# sname                     598
# dname                      59
# cname                       1
# enroll12                    1
# numtsttakr12                1
# numerwbenchmark12         276
# pcterwbenchmark12         276
# nummathbenchmark12        276
# pctmathbenchmark12        276
# enroll11                    1
# numtsttakr11                1
# numerwbenchmark11         311
# pcterwbenchmark11         311
# nummathbenchmark11        311
# pctmathbenchmark11        311
# totnumbothbenchmark12     276
# pctbothbenchmark12        276
# totnumbothbenchmark11     311
# pctbothbenchmark11        311
# year                        1
# unnamed: 25              2580
# dtype: int64

# %%
sat_2019c.describe()
# Out:
#                 cds        ccode        cdcode         scode       enroll12  \
# count  2.579000e+03  2579.000000  2.579000e+03  2.579000e+03    2579.000000
# mean   2.915139e+13    28.519581  2.915138e+06  1.544913e+06     748.155487
# std    1.428328e+13    14.258173  1.428327e+06  1.812049e+06   10095.758681
# min    0.000000e+00     0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%    1.964725e+13    19.000000  1.964725e+06  1.025080e+05      63.000000
# 50%    3.066597e+13    30.000000  3.066597e+06  1.377860e+05     171.000000
# 75%    3.777103e+13    37.000000  3.777103e+06  3.037422e+06     462.000000
# max    5.872770e+13    58.000000  5.872769e+06  6.120893e+06  489650.000000
#
#         numtsttakr12       enroll11   numtsttakr11  unnamed: 25
# count    2579.000000    2579.000000    2579.000000          0.0
# mean      264.274137     730.865452     320.473052          NaN
# std      3568.205236    9792.971460    4396.615761          NaN
# ...

# %%
sat_2019c.describe(include='all')
# Out:
#                  cds        ccode        cdcode         scode rtype  \
# count   2.579000e+03  2579.000000  2.579000e+03  2.579000e+03  2579
# unique           NaN          NaN           NaN           NaN     4
# top              NaN          NaN           NaN           NaN     S
# freq             NaN          NaN           NaN           NaN  1981
# mean    2.915139e+13    28.519581  2.915138e+06  1.544913e+06   NaN
# std     1.428328e+13    14.258173  1.428327e+06  1.812049e+06   NaN
# min     0.000000e+00     0.000000  0.000000e+00  0.000000e+00   NaN
# 25%     1.964725e+13    19.000000  1.964725e+06  1.025080e+05   NaN
# 50%     3.066597e+13    30.000000  3.066597e+06  1.377860e+05   NaN
# 75%     3.777103e+13    37.000000  3.777103e+06  3.037422e+06   NaN
# max     5.872770e+13    58.000000  5.872769e+06  6.120893e+06   NaN
#
#                       sname                dname        cname       enroll12  \
# ...

# %%
# 5 rows of sat2019 cali data
print(sat_2019c.shape)
sat_2019c.head()
# Out:
# (2580, 26)
#             cds  ccode     cdcode      scode rtype                    sname  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  dname        cname  enroll12  numtsttakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   numerwbenchmark11 pcterwbenchmark11 nummathbenchmark11 pctmathbenchmark11  \
# ...

# %%
#31, no value 
sat_2019ca_count[sat_2019ca_count.numerwbenchmark12.isnull()== True]
# Out:
#              cds  ccode    cdcode  scode rtype sname dname   cname  enroll12  \
# 31  2.000000e+12    2.0  200000.0    0.0     C   NaN   NaN  Alpine       0.0
#
#     numtsttakr12  ... numerwbenchmark11 pcterwbenchmark11 nummathbenchmark11  \
# 31           0.0  ...               NaN               NaN                NaN
#
#    pctmathbenchmark11  totnumbothbenchmark12  pctbothbenchmark12  \
# 31                NaN                    NaN                 NaN
#
#    totnumbothbenchmark11 pctbothbenchmark11     year unnamed: 25
# 31                   NaN                NaN  2018-19         NaN
#
# [1 rows x 26 columns]

# %%
# Convert str to float first
sat_2019ca_count[sat_2019ca_count.numerwbenchmark12=='*']
# Out:
#              cds  ccode     cdcode  scode rtype sname dname    cname  \
# 7   4.600000e+13   46.0  4600000.0    0.0     C   NaN   NaN   Sierra
# 37  5.300000e+13   53.0  5300000.0    0.0     C   NaN   NaN  Trinity
#
#     enroll12  numtsttakr12  ... numerwbenchmark11 pcterwbenchmark11  \
# 7       23.0           5.0  ...                 *                 *
# 37     154.0          13.0  ...                28             82.35
#
#    nummathbenchmark11 pctmathbenchmark11  totnumbothbenchmark12  \
# 7                   *                  *                      *
# 37                 24              70.59                      *
#
#     pctbothbenchmark12 totnumbothbenchmark11 pctbothbenchmark11     year  \
# 7                    *                     *                  *  2018-19
# 37                   *                    23              67.65  2018-19
#
#    unnamed: 25
# 7          NaN
# 37         NaN
#
# [2 rows x 26 columns]

# %%
# change the '*' to np.nan
sat_2019ca_count.replace('*',np.nan, inplace=True)
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\frame.py:4524: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
#now * is NaN converted
sat_2019ca_count[(sat_2019ca_count.cname=='Sierra')|(sat_2019ca_count.cname=='Trinity')]
# Out:
#              cds  ccode     cdcode  scode rtype  sname  dname    cname  \
# 7   4.600000e+13   46.0  4600000.0    0.0     C    NaN    NaN   Sierra
# 37  5.300000e+13   53.0  5300000.0    0.0     C    NaN    NaN  Trinity
#
#     enroll12  numtsttakr12  ... numerwbenchmark11 pcterwbenchmark11  \
# 7       23.0           5.0  ...               NaN               NaN
# 37     154.0          13.0  ...                28             82.35
#
#    nummathbenchmark11 pctmathbenchmark11  totnumbothbenchmark12  \
# 7                 NaN                NaN                    NaN
# 37                 24              70.59                    NaN
#
#     pctbothbenchmark12 totnumbothbenchmark11 pctbothbenchmark11     year  \
# 7                  NaN                   NaN                NaN  2018-19
# 37                 NaN                    23              67.65  2018-19
#
#    unnamed: 25
# 7          NaN
# 37         NaN
#
# [2 rows x 26 columns]

# %%
#convert columns
print(sat_2019ca_count.columns[10:14])
print(sat_2019ca_count.columns[16:24])
# Out:
# Index(['numerwbenchmark12', 'pcterwbenchmark12', 'nummathbenchmark12',
#        'pctmathbenchmark12'],
#       dtype='object')
# Index(['numerwbenchmark11', 'pcterwbenchmark11', 'nummathbenchmark11',
#        'pctmathbenchmark11', 'totnumbothbenchmark12', 'pctbothbenchmark12',
#        'totnumbothbenchmark11', 'pctbothbenchmark11'],
#       dtype='object')

# %%
#checking row 10 to 14 and 16 to 24 all object 
sat_2019ca_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cds                    58 non-null     float64
#  1   ccode                  58 non-null     float64
#  2   cdcode                 58 non-null     float64
#  3   scode                  58 non-null     float64
#  4   rtype                  58 non-null     object
#  5   sname                  0 non-null      float64
#  6   dname                  0 non-null      float64
#  7   cname                  58 non-null     object
#  8   enroll12               58 non-null     float64
#  9   numtsttakr12           58 non-null     float64
#  10  numerwbenchmark12      55 non-null     object
#  11  pcterwbenchmark12      55 non-null     object
#  12  nummathbenchmark12     55 non-null     object
#  13  pctmathbenchmark12     55 non-null     object
# ...

# %%
#convert float
for column in sat_2019ca_count.columns[10:14]:
    sat_2019ca_count[column] = sat_2019ca_count[column].apply(lambda x: float(x))
# Out:
# <ipython-input-48-56065771546b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_2019ca_count[column] = sat_2019ca_count[column].apply(lambda x: float(x))

# %%
sat_2019ca_count[sat_2019ca_count.columns[10:14]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   numerwbenchmark12   55 non-null     float64
#  1   pcterwbenchmark12   55 non-null     float64
#  2   nummathbenchmark12  55 non-null     float64
#  3   pctmathbenchmark12  55 non-null     float64
# dtypes: float64(4)
# memory usage: 1.9 KB

# %%
for column in sat_2019ca_count.columns[16:24]:
    sat_2019ca_count[column] = sat_2019ca_count[column].apply(lambda x: float(x))
# Out:
# <ipython-input-50-4d1ff4e10bd6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_2019ca_count[column] = sat_2019ca_count[column].apply(lambda x: float(x))

# %%
print(sat_2019ca_count.info()) #float converteds
sat_2019ca_count.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cds                    58 non-null     float64
#  1   ccode                  58 non-null     float64
#  2   cdcode                 58 non-null     float64
#  3   scode                  58 non-null     float64
#  4   rtype                  58 non-null     object
#  5   sname                  0 non-null      float64
#  6   dname                  0 non-null      float64
#  7   cname                  58 non-null     object
#  8   enroll12               58 non-null     float64
#  9   numtsttakr12           58 non-null     float64
#  10  numerwbenchmark12      55 non-null     float64
#  11  pcterwbenchmark12      55 non-null     float64
#  12  nummathbenchmark12     55 non-null     float64
#  13  pctmathbenchmark12     55 non-null     float64
# ...

# %%
#changing column with pct to percentge
pct_c = [sat_2019ca_count.columns[11], sat_2019ca_count.columns[13], sat_2019ca_count.columns[17],
        sat_2019ca_count.columns[19], sat_2019ca_count.columns[21], sat_2019ca_count.columns[23]]

pct_c
# Out:
# ['pcterwbenchmark12',
#  'pctmathbenchmark12',
#  'pcterwbenchmark11',
#  'pctmathbenchmark11',
#  'pctbothbenchmark12',
#  'pctbothbenchmark11']

# %%
# convert pct to percentage
for column in pct_c:
    sat_2019ca_count[column] = sat_2019ca_count[column].apply(lambda x: (x/100))
# Out:
# <ipython-input-53-9ab97b0c8d77>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_2019ca_count[column] = sat_2019ca_count[column].apply(lambda x: (x/100))

# %%
sat_2019ca_count.head()
# Out:
#             cds  ccode     cdcode  scode rtype  sname  dname        cname  \
# 0  9.000000e+12    9.0   900000.0    0.0     C    NaN    NaN    El Dorado
# 1  1.900000e+13   19.0  1900000.0    0.0     C    NaN    NaN  Los Angeles
# 2  2.000000e+13   20.0  2000000.0    0.0     C    NaN    NaN       Madera
# 3  5.700000e+13   57.0  5700000.0    0.0     C    NaN    NaN         Yolo
# 4  1.500000e+13   15.0  1500000.0    0.0     C    NaN    NaN         Kern
#
#    enroll12  numtsttakr12  ...  numerwbenchmark11  pcterwbenchmark11  \
# 0    2226.0         604.0  ...              667.0             0.9355
# 1  114618.0       48676.0  ...            39363.0             0.5765
# 2    2352.0         442.0  ...              608.0             0.4713
# 3    2299.0         759.0  ...              709.0             0.8885
# 4   14229.0        3793.0  ...             2077.0             0.7447
#
#    nummathbenchmark11  pctmathbenchmark11  totnumbothbenchmark12  \
# ...

# %%
drop_cs = list(sat_2019ca_count.columns[0:7]) + list(sat_2019ca_count.columns[-2:])
drop_cs
# Out:
# ['cds',
#  'ccode',
#  'cdcode',
#  'scode',
#  'rtype',
#  'sname',
#  'dname',
#  'year',
#  'unnamed: 25']

# %%
sat_2019ca_count.drop(columns=drop_cs,inplace=True) #drop all useless columns
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
print(sat_2019ca_count.info())
sat_2019ca_count.head() #column that left
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cname                  58 non-null     object
#  1   enroll12               58 non-null     float64
#  2   numtsttakr12           58 non-null     float64
#  3   numerwbenchmark12      55 non-null     float64
#  4   pcterwbenchmark12      55 non-null     float64
#  5   nummathbenchmark12     55 non-null     float64
#  6   pctmathbenchmark12     55 non-null     float64
#  7   enroll11               58 non-null     float64
#  8   numtsttakr11           58 non-null     float64
#  9   numerwbenchmark11      55 non-null     float64
#  10  pcterwbenchmark11      55 non-null     float64
#  11  nummathbenchmark11     55 non-null     float64
#  12  pctmathbenchmark11     55 non-null     float64
#  13  totnumbothbenchmark12  55 non-null     float64
# ...

# %%
sat_2019ca_count[sat_2019ca_count.numerwbenchmark11.isnull()]
# Out:
#      cname  enroll12  numtsttakr12  numerwbenchmark12  pcterwbenchmark12  \
# 7   Sierra      23.0           5.0                NaN                NaN
# 31  Alpine       0.0           0.0                NaN                NaN
# 48   Modoc      87.0          16.0               12.0               0.75
#
#     nummathbenchmark12  pctmathbenchmark12  enroll11  numtsttakr11  \
# 7                  NaN                 NaN      31.0          14.0
# 31                 NaN                 NaN       0.0           0.0
# 48                 9.0              0.5625      96.0          14.0
#
#     numerwbenchmark11  pcterwbenchmark11  nummathbenchmark11  \
# 7                 NaN                NaN                 NaN
# 31                NaN                NaN                 NaN
# 48                NaN                NaN                 NaN
#
#     pctmathbenchmark11  totnumbothbenchmark12  pctbothbenchmark12  \
# 7                  NaN                    NaN                 NaN
# ...

# %%
sat_2019ca_count.rename(columns={'cname':'county',}, #convert name cname to county so can merge with other data
                          inplace=True)
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
#Add two new columns , participation rate for Grade 12 /11
sat_2019ca_count['participation_rate12'] = sat_2019ca_count.numtsttakr12/sat_2019ca_count.enroll12
sat_2019ca_count['participation_rate11'] = sat_2019ca_count.numtsttakr11/sat_2019ca_count.enroll11
# Out:
# <ipython-input-60-6e4e989ed973>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_2019ca_count['participation_rate12'] = sat_2019ca_count.numtsttakr12/sat_2019ca_count.enroll12
# <ipython-input-60-6e4e989ed973>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_2019ca_count['participation_rate11'] = sat_2019ca_count.numtsttakr11/sat_2019ca_count.enroll11

# %%
#lets see
print(sat_2019ca_count.info())
sat_2019ca_count.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   county                 58 non-null     object
#  1   enroll12               58 non-null     float64
#  2   numtsttakr12           58 non-null     float64
#  3   numerwbenchmark12      55 non-null     float64
#  4   pcterwbenchmark12      55 non-null     float64
#  5   nummathbenchmark12     55 non-null     float64
#  6   pctmathbenchmark12     55 non-null     float64
#  7   enroll11               58 non-null     float64
#  8   numtsttakr11           58 non-null     float64
#  9   numerwbenchmark11      55 non-null     float64
#  10  pcterwbenchmark11      55 non-null     float64
#  11  nummathbenchmark11     55 non-null     float64
#  12  pctmathbenchmark11     55 non-null     float64
#  13  totnumbothbenchmark12  55 non-null     float64
# ...

# %% [markdown]
# ### Import the median household income for 2019 from:
# https://www.census.gov/search-results.html?q=california+median+income&page=1&stateGeo=none&searchtype=web&cssp=SERP&_charset_=UTF-8

# %%
# Other data
income_c = pd.read_csv('../data/household_income_county.csv')

# %%
print(income_c.info())
income_c.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Median Household Income by County  60 non-null     object
#  1   Unnamed: 1                         59 non-null     object
#  2   Unnamed: 2                         59 non-null     object
# dtypes: object(3)
# memory usage: 1.5+ KB
# None
#   Median Household Income by County Unnamed: 1       Unnamed: 2
# 0                            County     Income  Margin Of Error
# 1                    Alameda County    $99,406         +/- $921
# 2                     Alpine County    $63,750      +/- $17,778
# 3                     Amador County    $62,772       +/- $2,756
# 4                      Butte County    $52,537       +/- $1,618

# %%
#lets drop 0 & 59 as useless
income_c.iloc[0::59]
# Out:
#                     Median Household Income by County Unnamed: 1  \
# 0                                              County     Income
# 59  Source(s): U.S. Census Bureau, 2015-2019 Ameri...        NaN
#
#          Unnamed: 2
# 0   Margin Of Error
# 59              NaN

# %%
income_c.drop(index=[0,59],inplace=True)

# %%
income_c.reset_index(drop=True, inplace=True)

# %%
# cleaning the symbol
income_c['Unnamed: 1'] = income_c['Unnamed: 1'].str.replace('$','').str.replace(',','')
# Out:
# <ipython-input-67-629e6b8be308>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   income_c['Unnamed: 1'] = income_c['Unnamed: 1'].str.replace('$','').str.replace(',','')

# %%
income_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 3 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Median Household Income by County  58 non-null     object
#  1   Unnamed: 1                         58 non-null     object
#  2   Unnamed: 2                         58 non-null     object
# dtypes: object(3)
# memory usage: 1.5+ KB

# %%
#convet to int
income_c['Unnamed: 1'] = income_c['Unnamed: 1'].apply(lambda x: int(x))

# %%
income_c.info()
income_c.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 3 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Median Household Income by County  58 non-null     object
#  1   Unnamed: 1                         58 non-null     int64
#  2   Unnamed: 2                         58 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.5+ KB
#   Median Household Income by County  Unnamed: 1   Unnamed: 2
# 0                    Alameda County       99406     +/- $921
# 1                     Alpine County       63750  +/- $17,778
# 2                     Amador County       62772   +/- $2,756
# 3                      Butte County       52537   +/- $1,618
# 4                  Calaveras County       63158   +/- $4,128

# %%
income_c.rename(columns={'Median Household Income by County':'county', 'Unnamed: 1': 'md_hh_income'}, inplace=True) 
#for merging later

# %%
#not using unnamed 2 so gonna drop it
income_c.drop(columns='Unnamed: 2',inplace= True)

# %%
income_c.info()
income_c.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   county        58 non-null     object
#  1   md_hh_income  58 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB
#              county  md_hh_income
# 0    Alameda County         99406
# 1     Alpine County         63750
# 2     Amador County         62772
# 3      Butte County         52537
# 4  Calaveras County         63158

# %%
income_c.county = income_c.county.str.replace(' County','') #remove gap infront of county

# %%
income_c.head()
# Out:
#       county  md_hh_income
# 0    Alameda         99406
# 1     Alpine         63750
# 2     Amador         62772
# 3      Butte         52537
# 4  Calaveras         63158

# %%
sat_2019ca_count= pd.merge(left= sat_2019ca_count, right= income_c, how='right', on='county')

# %%
sat_2019ca_count
# Out:
#              county  enroll12  numtsttakr12  numerwbenchmark12  \
# 0           Alameda   17567.0        5946.0             4566.0
# 1            Alpine       0.0           0.0                NaN
# 2            Amador     305.0          53.0               44.0
# 3             Butte    2551.0         551.0              453.0
# 4         Calaveras     451.0          90.0               81.0
# 5            Colusa     339.0          74.0               39.0
# 6      Contra Costa   14593.0        5412.0             3798.0
# 7         Del Norte     363.0          72.0               50.0
# 8         El Dorado    2226.0         604.0              547.0
# 9            Fresno   14299.0        4070.0             2664.0
# 10            Glenn     500.0          90.0               58.0
# 11         Humboldt    1342.0         300.0              250.0
# 12         Imperial    3168.0         775.0              540.0
# 13             Inyo     548.0          88.0               47.0
# ...

# %% [markdown]
# ### These files will be use:
# ### sat_2017to2019 and sat_2019ca_count

# %%
sat_2019ca_count[sat_2019ca_count.county=='Santa Barbara']
# Out:
#            county  enroll12  numtsttakr12  numerwbenchmark12  \
# 41  Santa Barbara    5304.0        1211.0              978.0
#
#     pcterwbenchmark12  nummathbenchmark12  pctmathbenchmark12  enroll11  \
# 41             0.8076               754.0              0.6226    5090.0
#
#     numtsttakr11  numerwbenchmark11  pcterwbenchmark11  nummathbenchmark11  \
# 41        1785.0             1329.0             0.7445              1070.0
#
#     pctmathbenchmark11  totnumbothbenchmark12  pctbothbenchmark12  \
# 41              0.5994                  727.0              0.6003
#
#     totnumbothbenchmark11  pctbothbenchmark11  participation_rate12  \
# 41                 1014.0              0.5681              0.228318
#
#     participation_rate11  md_hh_income
# 41              0.350688         74624

# %%
sat_2019ca_count.sort_values(by='enroll12', ascending=False)
# Out:
#              county  enroll12  numtsttakr12  numerwbenchmark12  \
# 18      Los Angeles  114618.0       48676.0            30081.0
# 36        San Diego   42040.0       12872.0            10086.0
# 29           Orange   41235.0       16061.0            11463.0
# 32        Riverside   34277.0       14070.0             8572.0
# 35   San Bernardino   31635.0       10544.0             7014.0
# 42      Santa Clara   21656.0        6920.0             5741.0
# 33       Sacramento   19540.0        6090.0             4138.0
# 0           Alameda   17567.0        5946.0             4566.0
# 6      Contra Costa   14593.0        5412.0             3798.0
# 9            Fresno   14299.0        4070.0             2664.0
# 14             Kern   14229.0        3793.0             2334.0
# 38      San Joaquin   11778.0        3351.0             2344.0
# 55          Ventura   10750.0        4534.0             2815.0
# 49       Stanislaus    9071.0        2373.0             1605.0
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*string*|2017 SAT Scores by State|States in the USA
# |**participation_2017**|*float*|2017 SAT Scores by State|Participation rates for SAT in 2017 by state
# |**ebrw_2017**|*float*|2017 SAT Scores by State|Average SAT Evidence-based Reading and Writing Score in 2017 by state
# |**math_2017**|*float*|2017 SAT Scores by State|Average SAT Mathematics Score in 2017 by state
# |**total_2017**|*float*|2017 SAT Scores by State|Average SAT Total Score in 2017 by state, where Total = Math + EBRW
# |**participation_2018**|*float*|2018 SAT Scores by State|Participation rates for SAT in 2018 by state
# |**ebrw_2018**|*float*|2018 SAT Scores by State|Average SAT Evidence-based Reading and Writing Score in 2018 by state
# |**math_2018**|*float*|2018 SAT Scores by State|Average SAT Mathematics Score in 2018 by state
# |**total_2018**|*float*|2018 SAT Scores by State|Average SAT Total Score in 2018 by state, where Total = Math + EBRW
# **participation_2019**|*float*|2019 SAT Scores by State|Participation rates for SAT in 2019 by state
# |**ebrw_2019**|*float*|2019 SAT Scores by State|Average SAT Evidence-based Reading and Writing Score in 2019 by state
# |**math_2019**|*float*|2019 SAT Scores by State|Average SAT Mathematics Score in 2019 by state
# |**total_2019**|*float*|2019 SAT Scores by State|Average SAT Total Score in 2019 by state, where Total = Math + EBRW

# %% [markdown]
# ### Data Dictionary for sat_2019_ca_county

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**County**|*string*|2019 SAT Scores in California by School|Counties in the state of California
# |**enroll_12**|*float*|2019 SAT Scores in California by School|Enrollment for Grade 12 by county
# |**tst_tkr_12**|*float*|2019 SAT Scores in California by School|Number of SAT takers in Grade 12 by county
# |**num_erw_bm_12**|*float*|2019 SAT Scores in California by School|Number of students meeting the Evidence-Based Reading & Writing (ERW) benchmark established by the College Board based on the New 2016 SAT test format as of March 2016 for Grade 12
# |**pct_erw_bm_12**|*float*|2019 SAT Scores in California by School|Percentage of students who meet or exceeded the benchmark for Evidence-Based Reading & Writing (ERW) test for Grade 12
# |**num_math_bm_12**|*float*|2019 SAT Scores in California by School|Number of students who met or exceeded the benchmark for the New 2016 SAT Math test format as of March 2016 for Grade 12
# |**pct_math_bm_12**|*float*|2019 SAT Scores in California by School|Percentage of students who met or exceeded the benchmark for SAT Math test for Grade 12
# |**enroll_11**|*float*|2019 SAT Scores in California by School|Enrollment for Grade 11 by county
# |**tst_tkr_11**|*float*|2019 SAT Scores in California by School|Number of SAT takers in Grade 11 by county
# |**num_erw_bm_11**|*float*|2019 SAT Scores in California by School|Number of students meeting the Evidence-Based Reading & Writing (ERW) benchmark established by the College Board based on the New 2016 SAT test format as of March 2016 for Grade 11
# |**pct_erw_bm_11**|*float*|2019 SAT Scores in California by School|Percentage of students who meet or exceeded the benchmark for Evidence-Based Reading & Writing (ERW) test for Grade 11
# |**num_math_bm_11**|*float*|2019 SAT Scores in California by School|Number of students who met or exceeded the benchmark for the New 2016 SAT Math test format as of March 2016 for Grade 11
# |**pct_math_bm_11**|*float*|2019 SAT Scores in California by School|Percentage of students who met or exceeded the benchmark for SAT Math test for Grade 11
# |**num_both_bm_12**|*float*|2019 SAT Scores in California by School|Number of students who met the benchmark for Evidence-Based Reading & Writing (ERW) and Math Grade 12
# |**pct_both_bm_12**|*float*|2019 SAT Scores in California by School|Percentage of students who met the benchmark for Evidence-Based Reading & Writing (ERW) and Math Grade 12
# |**num_both_bm_11**|*float*|2019 SAT Scores in California by School|Number of students who met the benchmark for Evidence-Based Reading & Writing (ERW) and Math Grade 11
# |**pct_both_bm_11**|*float*|2019 SAT Scores in California by School|Percentage of students who met the benchmark for Evidence-Based Reading & Writing (ERW) and Math Grade 11
# |**participation_rate_12**|*float*|2019 SAT Scores in California by School| SAT participation rate for Grade 12 by county
# |**participation_rate_11**|*float*|2019 SAT Scores in California by School|SAT participation rate for Grade 11 by county
# |**median_hh_income**|*integer*|2019 California Median Household Income|The annual median household income by county in California for 2019

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### SD for sat_2017_to_2019

# %%
sat_2017to2019.head()
# Out:
#         state  2017_participation  ebrw_2017  math_2017  total_2017  \
# 0     Alabama                0.05      593.0      572.0      1165.0
# 1      Alaska                0.38      547.0      533.0      1080.0
# 2     Arizona                0.30      563.0      553.0      1116.0
# 3    Arkansas                0.03      614.0      594.0      1208.0
# 4  California                0.53      531.0      524.0      1055.0
#
#    2018_participation  ebrw_2018  math_2018  total_2018  2019_participation  \
# 0                0.06      595.0      571.0      1166.0                0.07
# 1                0.43      562.0      544.0      1106.0                0.41
# 2                0.29      577.0      572.0      1149.0                0.31
# 3                0.05      592.0      576.0      1169.0                0.06
# 4                0.60      540.0      536.0      1076.0                0.63
#
#    ebrw_2019  math_2019  total_2019
# 0        583        560        1143
# ...

# %%
# numeric columns are: 
sat_2017to2019.columns[1:]
# Out:
# Index(['2017_participation', 'ebrw_2017', 'math_2017', 'total_2017',
#        '2018_participation', 'ebrw_2018', 'math_2018', 'total_2018',
#        '2019_participation', 'ebrw_2019', 'math_2019', 'total_2019'],
#       dtype='object')

# %%
sat_2017to2019.describe()
# Out:
#        2017_participation   ebrw_2017   math_2017   total_2017  \
# count           51.000000   51.000000   51.000000    51.000000
# mean             0.398039  569.117647  547.627451  1126.098039
# std              0.352766   45.666901   84.909119    92.494812
# min              0.020000  482.000000   52.000000   950.000000
# 25%              0.040000  533.500000  522.000000  1055.500000
# 50%              0.380000  559.000000  548.000000  1107.000000
# 75%              0.660000  613.000000  599.000000  1212.000000
# max              1.000000  644.000000  651.000000  1295.000000
#
#        2018_participation   ebrw_2018   math_2018   total_2018  \
# count           51.000000   51.000000   51.000000    51.000000
# mean             0.457451  563.686275  556.235294  1120.019608
# std              0.373143   47.502627   47.772623    94.155083
# min              0.020000  480.000000  480.000000   977.000000
# 25%              0.045000  534.500000  522.500000  1057.500000
# ...

# %%
sat_2017to2019.std(ddof=0)
# Out:
# 2017_participation     0.349291
# ebrw_2017             45.216970
# math_2017             84.072555
# total_2017            91.583511
# 2018_participation     0.369466
# ebrw_2018             47.034610
# math_2018             47.301946
# total_2018            93.227424
# 2019_participation     0.383658
# ebrw_2019             45.792379
# math_2019             50.785215
# total_2019            96.240272
# dtype: float64

# %%
sat_2017to2019[['ebrw_2017']].apply(std_dev)
# Out:
# ebrw_2017    45.21697
# dtype: float64

# %%
sat_2017to2019[['ebrw_2017']].apply(mean_calculation)
# Out:
# ebrw_2017    569.117647
# dtype: float64

# %%
sdv = dict(zip(sat_2017to2019.columns[1:], sat_2017to2019[sat_2017to2019.columns[1:]].apply(std_dev)))
sdv
# Out:
# {'2017_participation': 0.3492907076664507,
#  'ebrw_2017': 45.21697020437866,
#  'math_2017': 84.07255521608297,
#  'total_2017': 91.58351056778743,
#  '2018_participation': 0.3694661922353942,
#  'ebrw_2018': 47.03460978357609,
#  'math_2018': 47.30194550378352,
#  'total_2018': 93.22742384464433,
#  '2019_participation': 0.3836584048685726,
#  'ebrw_2019': 45.792378682545134,
#  'math_2019': 50.78521461840036,
#  'total_2019': 96.24027185617864}

# %% [markdown]
# ### SD for sat_2019_ca_county

# %%
sat_2019ca_count.head()
# Out:
#       county  enroll12  numtsttakr12  numerwbenchmark12  pcterwbenchmark12  \
# 0    Alameda   17567.0        5946.0             4566.0             0.7679
# 1     Alpine       0.0           0.0                NaN                NaN
# 2     Amador     305.0          53.0               44.0             0.8302
# 3      Butte    2551.0         551.0              453.0             0.8221
# 4  Calaveras     451.0          90.0               81.0             0.9000
#
#    nummathbenchmark12  pctmathbenchmark12  enroll11  numtsttakr11  \
# 0              3623.0              0.6093   17191.0        7608.0
# 1                 NaN                 NaN       0.0           0.0
# 2                35.0              0.6604     344.0          48.0
# 3               349.0              0.6334    2392.0         536.0
# 4                60.0              0.6667     450.0         106.0
#
#    numerwbenchmark11  pcterwbenchmark11  nummathbenchmark11  \
# ...

# %%
sat_2019ca_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 57
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   county                 58 non-null     object
#  1   enroll12               58 non-null     float64
#  2   numtsttakr12           58 non-null     float64
#  3   numerwbenchmark12      55 non-null     float64
#  4   pcterwbenchmark12      55 non-null     float64
#  5   nummathbenchmark12     55 non-null     float64
#  6   pctmathbenchmark12     55 non-null     float64
#  7   enroll11               58 non-null     float64
#  8   numtsttakr11           58 non-null     float64
#  9   numerwbenchmark11      55 non-null     float64
#  10  pcterwbenchmark11      55 non-null     float64
#  11  nummathbenchmark11     55 non-null     float64
#  12  pctmathbenchmark11     55 non-null     float64
#  13  totnumbothbenchmark12  55 non-null     float64
# ...

# %%
sat_2019ca_count_nonull = sat_2019ca_count[~sat_2019ca_count. numerwbenchmark12.isnull()]
sat_2019ca_count_nonull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 0 to 57
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   county                 55 non-null     object
#  1   enroll12               55 non-null     float64
#  2   numtsttakr12           55 non-null     float64
#  3   numerwbenchmark12      55 non-null     float64
#  4   pcterwbenchmark12      55 non-null     float64
#  5   nummathbenchmark12     55 non-null     float64
#  6   pctmathbenchmark12     55 non-null     float64
#  7   enroll11               55 non-null     float64
#  8   numtsttakr11           55 non-null     float64
#  9   numerwbenchmark11      54 non-null     float64
#  10  pcterwbenchmark11      54 non-null     float64
#  11  nummathbenchmark11     54 non-null     float64
#  12  pctmathbenchmark11     54 non-null     float64
#  13  totnumbothbenchmark12  55 non-null     float64
# ...

# %%
sat_2019ca_count_nonull = sat_2019ca_count[~sat_2019ca_count.numerwbenchmark11.isnull()]
sat_2019ca_count_nonull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 0 to 57
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   county                 55 non-null     object
#  1   enroll12               55 non-null     float64
#  2   numtsttakr12           55 non-null     float64
#  3   numerwbenchmark12      54 non-null     float64
#  4   pcterwbenchmark12      54 non-null     float64
#  5   nummathbenchmark12     54 non-null     float64
#  6   pctmathbenchmark12     54 non-null     float64
#  7   enroll11               55 non-null     float64
#  8   numtsttakr11           55 non-null     float64
#  9   numerwbenchmark11      55 non-null     float64
#  10  pcterwbenchmark11      55 non-null     float64
#  11  nummathbenchmark11     55 non-null     float64
#  12  pctmathbenchmark11     55 non-null     float64
#  13  totnumbothbenchmark12  54 non-null     float64
# ...

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %%
# numeric columns are: 
sat_2019ca_count_nonull.columns[1:]
# Out:
# Index(['enroll12', 'numtsttakr12', 'numerwbenchmark12', 'pcterwbenchmark12',
#        'nummathbenchmark12', 'pctmathbenchmark12', 'enroll11', 'numtsttakr11',
#        'numerwbenchmark11', 'pcterwbenchmark11', 'nummathbenchmark11',
#        'pctmathbenchmark11', 'totnumbothbenchmark12', 'pctbothbenchmark12',
#        'totnumbothbenchmark11', 'pctbothbenchmark11', 'participation_rate12',
#        'participation_rate11', 'md_hh_income'],
#       dtype='object')

# %%
sdca_count = dict(zip(sat_2019ca_count_nonull.columns[1:], 
                        sat_2019ca_count_nonull[sat_2019ca_count_nonull.columns[1:]].apply(std_dev)))
sdca_count
# Out:
# {'enroll12': 17541.23233512146,
#  'numtsttakr12': 7172.569292418544,
#  'numerwbenchmark12': nan,
#  'pcterwbenchmark12': nan,
#  'nummathbenchmark12': nan,
#  'pctmathbenchmark12': nan,
#  'enroll11': 17025.256136799722,
#  'numtsttakr11': 9723.532316435236,
#  'numerwbenchmark11': 5900.3265974880405,
#  'pcterwbenchmark11': 0.10414183002199731,
#  'nummathbenchmark11': 4132.775849412547,
#  'pctmathbenchmark11': 0.1514537687855236,
#  'totnumbothbenchmark12': nan,
#  'pctbothbenchmark12': nan,
#  'totnumbothbenchmark11': 3929.020886423285,
#  'pctbothbenchmark11': 0.15247468448324286,
#  'participation_rate12': 0.08850353508271297,
#  'participation_rate11': 0.12747183559292605,
#  'md_hh_income': 20228.899549239526}

# %% [markdown]
# ### Trends for sat_2017_to_2019

# %%
sat_2017to2019.head()
# Out:
#         state  2017_participation  ebrw_2017  math_2017  total_2017  \
# 0     Alabama                0.05      593.0      572.0      1165.0
# 1      Alaska                0.38      547.0      533.0      1080.0
# 2     Arizona                0.30      563.0      553.0      1116.0
# 3    Arkansas                0.03      614.0      594.0      1208.0
# 4  California                0.53      531.0      524.0      1055.0
#
#    2018_participation  ebrw_2018  math_2018  total_2018  2019_participation  \
# 0                0.06      595.0      571.0      1166.0                0.07
# 1                0.43      562.0      544.0      1106.0                0.41
# 2                0.29      577.0      572.0      1149.0                0.31
# 3                0.05      592.0      576.0      1169.0                0.06
# 4                0.60      540.0      536.0      1076.0                0.63
#
#    ebrw_2019  math_2019  total_2019
# 0        583        560        1143
# ...

# %%
sat_2017to2019.sort_values(by='2019_participation').head()
# Out:
#            state  2017_participation  ebrw_2017  math_2017  total_2017  \
# 34  North Dakota                0.02      635.0      621.0      1256.0
# 50       Wyoming                0.03      626.0      604.0      1230.0
# 41  South Dakota                0.03      612.0      603.0      1216.0
# 27      Nebraska                0.03      629.0      625.0      1253.0
# 49     Wisconsin                0.03      642.0      649.0      1291.0
#
#     2018_participation  ebrw_2018  math_2018  total_2018  2019_participation  \
# 34                0.02      640.0      643.0      1283.0                0.02
# 50                0.03      633.0      625.0      1257.0                0.03
# 41                0.03      622.0      618.0      1240.0                0.03
# 27                0.03      629.0      623.0      1252.0                0.03
# 49                0.03      641.0      653.0      1294.0                0.03
#
#     ebrw_2019  math_2019  total_2019
# 34        627        636        1263
# ...

# %% [markdown]
# ### North Dakota consistently has the lowest SAT participation rates for year 2017 to 2019.

# %%
sat_2017to2019[(sat_2017to2019['2017_participation']==1.0)|(sat_2017to2019['2018_participation']==1.0)|
                 (sat_2017to2019['2019_participation']==1.0)]
# Out:
#                    state  2017_participation  ebrw_2017  math_2017  \
# 5               Colorado                0.11      606.0      595.0
# 6            Connecticut                1.00      530.0      512.0
# 7               Delaware                1.00      503.0      492.0
# 8   District of Columbia                1.00      482.0      468.0
# 9                Florida                0.83      520.0      497.0
# 12                 Idaho                0.93      513.0      493.0
# 13              Illinois                0.09      559.0      556.0
# 22              Michigan                1.00      509.0      495.0
# 39          Rhode Island                0.71      539.0      524.0
#
#     total_2017  2018_participation  ebrw_2018  math_2018  total_2018  \
# 5       1201.0                1.00      519.0      506.0      1025.0
# 6       1041.0                1.00      535.0      519.0      1053.0
# 7        996.0                1.00      505.0      492.0       998.0
# ...

# %% [markdown]
# ### look like Idaho has 100% SAT participation rate , because some stated are compulsory.

# %% [markdown]
# ### Trends for sat_2019_ca_county

# %%
sat_2019ca_count.head()
# Out:
#       county  enroll12  numtsttakr12  numerwbenchmark12  pcterwbenchmark12  \
# 0    Alameda   17567.0        5946.0             4566.0             0.7679
# 1     Alpine       0.0           0.0                NaN                NaN
# 2     Amador     305.0          53.0               44.0             0.8302
# 3      Butte    2551.0         551.0              453.0             0.8221
# 4  Calaveras     451.0          90.0               81.0             0.9000
#
#    nummathbenchmark12  pctmathbenchmark12  enroll11  numtsttakr11  \
# 0              3623.0              0.6093   17191.0        7608.0
# 1                 NaN                 NaN       0.0           0.0
# 2                35.0              0.6604     344.0          48.0
# 3               349.0              0.6334    2392.0         536.0
# 4                60.0              0.6667     450.0         106.0
#
#    numerwbenchmark11  pcterwbenchmark11  nummathbenchmark11  \
# ...

# %%
sat_2019ca_count.sort_values(by='md_hh_income').head(10)
# Out:
#        county  enroll12  numtsttakr12  numerwbenchmark12  pcterwbenchmark12  \
# 52    Trinity     154.0          13.0                NaN                NaN
# 51     Tehama     688.0          91.0               69.0             0.7582
# 46   Siskiyou     462.0         109.0               83.0             0.7615
# 7   Del Norte     363.0          72.0               50.0             0.6944
# 24      Modoc      87.0          16.0               12.0             0.7500
# 16       Lake     667.0         167.0              123.0             0.7365
# 12   Imperial    3168.0         775.0              540.0             0.6968
# 11   Humboldt    1342.0         300.0              250.0             0.8333
# 21   Mariposa     155.0          36.0               33.0             0.9167
# 10      Glenn     500.0          90.0               58.0             0.6444
#
#     nummathbenchmark12  pctmathbenchmark12  enroll11  numtsttakr11  \
# ...

# %%
sat_2019ca_count.sort_values(by='md_hh_income' , ascending = False).head(10)
# Out:
#            county  enroll12  numtsttakr12  numerwbenchmark12  \
# 42    Santa Clara   21656.0        6920.0             5741.0
# 40      San Mateo    7235.0        3113.0             2410.0
# 20          Marin    2647.0         965.0              855.0
# 37  San Francisco    4447.0        2256.0             1579.0
# 6    Contra Costa   14593.0        5412.0             3798.0
# 0         Alameda   17567.0        5946.0             4566.0
# 29         Orange   41235.0       16061.0            11463.0
# 30         Placer    5931.0        1959.0             1709.0
# 27           Napa    1717.0         555.0              403.0
# 55        Ventura   10750.0        4534.0             2815.0
#
#     pcterwbenchmark12  nummathbenchmark12  pctmathbenchmark12  enroll11  \
# 42             0.8296              4796.0              0.6931   20501.0
# 40             0.7742              1945.0              0.6248    7216.0
# 20             0.8860               674.0              0.6984    2641.0
# ...

# %%
avg_numtsttakr11 = mean_calculation(sat_2019ca_count.numtsttakr11)
avg_numtsttakr11 #avg score of SAT in grade 11
# Out:
# 3562.793103448276

# %%
avg_numtsttakr12 = mean_calculation(sat_2019ca_count.numtsttakr12)
avg_numtsttakr12  #avg score of SAT in grade 12
# Out:
# 2938.1206896551726

# %%
overall_pr11 = sat_2019ca_count.numtsttakr11.sum()/sat_2019ca_count.enroll11.sum()
overall_pr11 # for plotting line on charts
# Out:
# 0.4351796277927652

# %%
overall_pr12 = sat_2019ca_count.numtsttakr12.sum()/sat_2019ca_count.enroll12.sum()
overall_pr12
# Out:
# 0.34802614112120905

# %%
poor_10 =sat_2019ca_count.sort_values(by='md_hh_income',ascending=True).head(10)
poor_10
# Out:
#        county  enroll12  numtsttakr12  numerwbenchmark12  pcterwbenchmark12  \
# 52    Trinity     154.0          13.0                NaN                NaN
# 51     Tehama     688.0          91.0               69.0             0.7582
# 46   Siskiyou     462.0         109.0               83.0             0.7615
# 7   Del Norte     363.0          72.0               50.0             0.6944
# 24      Modoc      87.0          16.0               12.0             0.7500
# 16       Lake     667.0         167.0              123.0             0.7365
# 12   Imperial    3168.0         775.0              540.0             0.6968
# 11   Humboldt    1342.0         300.0              250.0             0.8333
# 21   Mariposa     155.0          36.0               33.0             0.9167
# 10      Glenn     500.0          90.0               58.0             0.6444
#
#     nummathbenchmark12  pctmathbenchmark12  enroll11  numtsttakr11  \
# ...

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ### Relationship beween participation rate and average score nationwide

# %%
sat_2017to2019.head()
# Out:
#         state  2017_participation  ebrw_2017  math_2017  total_2017  \
# 0     Alabama                0.05      593.0      572.0      1165.0
# 1      Alaska                0.38      547.0      533.0      1080.0
# 2     Arizona                0.30      563.0      553.0      1116.0
# 3    Arkansas                0.03      614.0      594.0      1208.0
# 4  California                0.53      531.0      524.0      1055.0
#
#    2018_participation  ebrw_2018  math_2018  total_2018  2019_participation  \
# 0                0.06      595.0      571.0      1166.0                0.07
# 1                0.43      562.0      544.0      1106.0                0.41
# 2                0.29      577.0      572.0      1149.0                0.31
# 3                0.05      592.0      576.0      1169.0                0.06
# 4                0.60      540.0      536.0      1076.0                0.63
#
#    ebrw_2019  math_2019  total_2019
# 0        583        560        1143
# ...

# %%
plt.figure(figsize=(10,7))
sns.regplot(x='total_2017', y='2017_participation', data=sat_2017to2019,
            scatter_kws={'s':15, 'color':'olive'},line_kws={'color':'olive'}, ci=None, label='2017')
sns.regplot(x='total_2018', y='2018_participation', data=sat_2017to2019,
            scatter_kws={'s':15, 'color':'darkorange'},line_kws={'color':'darkorange'}, ci=None, label='2018')
sns.regplot(x="total_2019", y="2019_participation", data=sat_2017to2019,
            scatter_kws={'s':15, 'color':'pink'},line_kws={'color':'pink'}, ci=None, label='2019')
plt.xlabel("SAT Total Score")
plt.ylim(0,1.1)
plt.ylabel('SAT Participation Rate')
plt.legend(loc='upper right')
plt.title('SAT Total Score vs SAT Participation Rate');

# %% [markdown]
# ### SAT Participation rate and SAT Avg scores are negatively correlated.
# ### reasons are:
# - The higher SAT rates the higher student with different acedemic standards take part in the exam.
# - As the exam do not specify another requirement to standardlize who could participate
# - Thus lower average total score.

# %% [markdown]
# ### We can see this very evidently in states where SAT has become compulsory in 2018/19, but not compulsory in 2017. One example woulld be Colorado:

# %%
plt.figure(figsize=(10,7))
plt.bar('2017', sat_2017to2019[sat_2017to2019.state=='Colorado']['2017_participation'])
plt.bar('2018', sat_2017to2019[sat_2017to2019.state=='Colorado']['2018_participation'])
plt.bar('2019', sat_2017to2019[sat_2017to2019.state=='Colorado']['2019_participation'])
plt.xlabel('Years')
plt.ylabel('SAT Participation Rate')
plt.title('SAT Participation Rate in Colorado 2017-2019');

# %%
plt.figure(figsize=(10,7))
plt.bar('2017', sat_2017to2019[sat_2017to2019.state=='Colorado']['total_2017'])
plt.bar('2018', sat_2017to2019[sat_2017to2019.state=='Colorado']['total_2018'])
plt.bar('2019', sat_2017to2019[sat_2017to2019.state=='Colorado']['total_2019'])
plt.xlabel('Years')
plt.ylabel('Average SAT Total Score')
plt.ylim(810,1250)
plt.title('Average SAT Total Score 2017 to 2019');

# %%
sat_2019ca_count
# Out:
#              county  enroll12  numtsttakr12  numerwbenchmark12  \
# 0           Alameda   17567.0        5946.0             4566.0
# 1            Alpine       0.0           0.0                NaN
# 2            Amador     305.0          53.0               44.0
# 3             Butte    2551.0         551.0              453.0
# 4         Calaveras     451.0          90.0               81.0
# 5            Colusa     339.0          74.0               39.0
# 6      Contra Costa   14593.0        5412.0             3798.0
# 7         Del Norte     363.0          72.0               50.0
# 8         El Dorado    2226.0         604.0              547.0
# 9            Fresno   14299.0        4070.0             2664.0
# 10            Glenn     500.0          90.0               58.0
# 11         Humboldt    1342.0         300.0              250.0
# 12         Imperial    3168.0         775.0              540.0
# 13             Inyo     548.0          88.0               47.0
# ...

# %% [markdown]
# #plotting poor counties against average participation rates

# %%
#plotting poor counties against average participation rates Grade 12
plt.figure(figsize=(10,7))
plt.xticks(rotation=45, ha='right')
plt.title('SAT participation rates for Grade 12 by county')
plt.xlabel('County')
plt.ylabel('SAT Participation Rate')
plt.tight_layout
plt.bar(poor_10.sort_values(by='participation_rate12')['county'],
       poor_10.sort_values(by='participation_rate12')['participation_rate12'],
       label ='10 poorest Counties by Family Income', color='pink')


offset = 10
plt.text(offset, overall_pr12,overall_pr12, color='black')
plt.legend(loc='upper left')
plt.ylim(0,0.55);

# %%
#plotting poor counties against average participation rates Grade 11
plt.figure(figsize=(10,7))
plt.xticks(rotation=45, ha='right')
plt.title('SAT participation rates for Grade 11 by county')
plt.xlabel('County')
plt.ylabel('SAT Participation Rate')
plt.tight_layout
plt.bar(poor_10.sort_values(by='participation_rate11')['county'],
       poor_10.sort_values(by='participation_rate11')['participation_rate11'],
       label ='10 poorest Counties by Family Income', color='cyan')


offset = 10
plt.text(offset, overall_pr11,overall_pr11, color='black')
plt.legend(loc='upper left')
plt.ylim(0,0.55);

# %% [markdown]
# ### Relationship between SAT participation rates and Median Household Income

# %%
plt.figure(figsize=(10,7))
sns.regplot(x='md_hh_income', y='participation_rate12', ci=None, data=sat_2019ca_count,
            scatter_kws={'s':15,'color':'lightseagreen'},line_kws={'color':'lightseagreen'}, label='Grade 12')
sns.regplot(x='md_hh_income', y='participation_rate11', ci=None, data=sat_2019ca_count,
            scatter_kws={'s':15,'color':'royalblue'},line_kws={'color':'royalblue'}, label='Grade 11')
plt.xlabel('Median Household Income (USD)')
plt.ylabel('SAT Participation Rate')
plt.legend(loc='upper left')
plt.title('Median Household Income vs SAT Participation Rate');

# %% [markdown]
# ### SAT Participation rate and Median Household Income are positively correlated.
# ### reasons are:
# - The low SAT Participation rates the low Median household income is.
# - For example , points at relatively 0.2 SAT participation rate has around 25,000 Median household Income.
# - Thus this is a strong positive correlation between SAT Participation rate and Median household income.

# %%
#heatmap plot
plt.figure(figsize=(50,15))
corr = sat_2019ca_count.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)]=True
with sns.axes_style('white'):
    sns.heatmap(corr, mask = mask, square=True, annot= True, vmin= -1, vmax=1)

# %% [markdown]
# ### This heatmap backs up the data above.
# ### There is strong positive correlation (>0.5) between income and SAT participation rate.
# - Grade 11 Participation Rate vs Median Household Income = 0.56
# - Grade 12 Participation Rate vs Median Household Income = 0.69

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# ### Students with lower income background tend to have more challenges to take SAT than student from richer family background. Here we look to slove the issue in the low SAT participation rate which will in long run improve students from poor backgourd improves their grades.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!

# %% [markdown]
# ### References

# %% [markdown]
# 1) https://www.cnbc.com/2019/10/03/rich-students-get-better-sat-scores-heres-why.html

# %% [markdown]
# 2) https://collegereadiness.collegeboard.org/sat
