# %% [markdown]
# # Bunker Prices Prediction

# %% [markdown]
# In the past decades, oil markets have been seen as something close to perfect competition, impenetrable and prone to exogenous shocks, political, economic or other. Gas & Oil giants, Bunker trading firms would want to secure market competitiveness by having successful transactions with the best costing outcome.
#
# My Goal is to build a Time Series model to predict bunker price using Brent Crude. With the aid of 20 Major Ports price Average and Brent Crude Datasets, I would explore the relationships between commodities prices and determine the best model to companies stakeholders who entrsut their investing on.
#
# Nonetheless my main focus of product would be VLSFO Fuel Oil, IMO 2020 Grade, 0.5% as a new product available in the market.

# %% [markdown]
# **Datasets:**
# - Avg 20 major Port Bunker price
# - Brent Crude Price
#
# - 20 Major Ports:
#    - Busan, Colombo, Durban, Fujairah, Gibraltar, Hong Kong, Houston, Istanbul, LA/Long Beach, Las Palmas, Mumbai, New York, Panama, Piraeus, Rotterdam, Santos, Shanghai, Singapore, St Petersburg, Tokyo

# %% [markdown]
# **Table of content**
#   - Part 1: Data Exploration, Cleaning
#   - Part 2: Filtering by dates, setting variables
#   - Part 3: Arima Modeling
#   - Part 4: LSTM
#   - Part 5: Conclusion
#   - Part 6: Regression

# %% [markdown]
# Imports

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import datetime
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# Import Data

# %%
#import Crude prices
df= pd.read_csv('./data/Daily_Brent2022.csv')

# %%
#VLSFO (dated 2020 to 2022 Q1)
mpa20= pd.read_csv('./data/Daily_Bunker_Prices.csv')

# %% [markdown]
# Apply Function for EDA of Data

# %%
# Def function for EDA on dataframe
def eda(dataframe):
    print("dataframe shape \n", dataframe.shape, '\n')
    print("dataframe types \n", dataframe.dtypes, '\n')
    print("dataframe describe \n", dataframe.describe(), '\n')
    #print("dataframe describe \n", dataframe.describe(exclude=np.number).T, '\n')
    print("missing values \n", dataframe.isnull().sum(), '\n')
    print("duplicate values \n", dataframe.duplicated().sum(), '\n')
    print("dataframe columns \n", dataframe.columns, '\n')
    
#check if column is unique
    for i in dataframe.columns:
        print('{} is unique: {}'.format(i, dataframe[i].is_unique))

# %% [markdown]
# Part 1: Data Exploration

# %% [markdown]
# **Brent Crude**

# %%
#first 5 row 
df.head()
# Out:
#          Date  Price
# 0  05/20/1987  18.63
# 1  05/21/1987  18.45
# 2  05/22/1987  18.55
# 3  05/25/1987  18.60
# 4  05/26/1987  18.63

# %%
#apply function for eda
eda(df)
# Out:
# dataframe shape
#  (8815, 2)
#
# dataframe types
#  Date      object
# Price    float64
# dtype: object
#
# dataframe describe
#               Price
# count  8815.000000
# mean     47.157345
# std      32.052617
# min       9.100000
# 25%      18.950000
# 50%      35.720000
# 75%      68.415000
# max     143.950000
#
# missing values
#  Date     0
# Price    0
# dtype: int64
#
# duplicate values
#  0
#
# dataframe columns
#  Index(['Date', 'Price'], dtype='object')
#
# Date is unique: True
# Price is unique: False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8815 entries, 0 to 8814
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    8815 non-null   object
#  1   Price   8815 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 137.9+ KB

# %%
df['Price'].value_counts(normalize=True)
# Out:
# 18.48    0.002950
# 18.15    0.002496
# 16.85    0.002269
# 18.63    0.002042
# 17.00    0.002042
#            ...
# 45.54    0.000113
# 68.53    0.000113
# 28.83    0.000113
# 18.76    0.000113
# 55.06    0.000113
# Name: Price, Length: 4867, dtype: float64

# %%
#Change Date column to be datetime
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date  Price
# 0 1987-05-20  18.63
# 1 1987-05-21  18.45
# 2 1987-05-22  18.55
# 3 1987-05-25  18.60
# 4 1987-05-26  18.63

# %%
#setting date to index 
df.index = df.pop('Date')

# %%
df
# Out:
#             Price
# Date
# 1987-05-20  18.63
# 1987-05-21  18.45
# 1987-05-22  18.55
# 1987-05-25  18.60
# 1987-05-26  18.63
# ...           ...
# 2022-02-01  90.24
# 2022-02-02  91.43
# 2022-02-03  92.99
# 2022-02-04  96.86
# 2022-02-07  97.28
#
# [8815 rows x 1 columns]

# %%
#lets have a look at our data
#price1= df['Price']
plt.plot(df.index,df['Price'])

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Price'])
plt.title(label = 'Daily Crude Price', fontsize=18)
plt.show();

# %%
plt.boxplot(df['Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cba7877d30>,
#   <matplotlib.lines.Line2D at 0x1cba78880d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1cba7888430>,
#   <matplotlib.lines.Line2D at 0x1cba7888790>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1cba78779d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cba7888af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cba7888e50>],
#  'means': []}

# %%
bin_series = pd.cut(df['Price'],bins = 4).value_counts()
bin_series
# Out:
# (8.965, 42.812]      4717
# (42.812, 76.525]     2492
# (76.525, 110.237]    1118
# (110.237, 143.95]     488
# Name: Price, dtype: int64

# %%
values = bin_series.to_list()
values
# Out:
# [4717, 2492, 1118, 488]

# %%
labels = [str(x) for x in bin_series.index.to_list()]
labels
# Out:
# ['(8.965, 42.812]',
#  '(42.812, 76.525]',
#  '(76.525, 110.237]',
#  '(110.237, 143.95]']

# %%
plt.pie(values, labels= labels, autopct= '%1.2f%%')
plt.title('Distribution of Crude Price')
# Out:
# Text(0.5, 1.0, 'Distribution of Crude Price')

# %% [markdown]
# Part 2: Filtering by dates,Different time stamps, setting variables

# %%
# week average
df1= df.resample('W').mean()
df1.head()

#month average
df2= df.resample('M').mean()
df2.head()

#Year Average
df3=df.resample('Y').mean()
df3.head()

# show all mean in different time stamps
print("Daily avg \n", df.head(), '\n')
print("Weekly avg \n", df1.head(), '\n')
print("Monthly avg \n", df2.head(), '\n')
print("Yearly avg \n", df3.head(), '\n')
# Out:
# Daily avg
#              Price
# Date
# 1987-05-20  18.63
# 1987-05-21  18.45
# 1987-05-22  18.55
# 1987-05-25  18.60
# 1987-05-26  18.63
#
# Weekly avg
#                  Price
# Date
# 1987-05-24  18.543333
# 1987-05-31  18.602000
# 1987-06-07  18.702000
# 1987-06-14  18.754000
# 1987-06-21  19.007500
#
# Monthly avg
#                  Price
# Date
# 1987-05-31  18.580000
# 1987-06-30  18.860476
# 1987-07-31  19.856522
# 1987-08-31  18.979524
# 1987-09-30  18.313182
#
# Yearly avg
#                  Price
# Date
# 1987-12-31  18.525813
# 1988-12-31  14.905412
# 1989-12-31  18.228228
# 1990-12-31  23.761445
# 1991-12-31  20.041128

# %%
# lot pairplot for all mean
print("Daily avg \n", sns.pairplot(df), '\n')
print("Weekly avg \n", sns.pairplot(df1), '\n')
print("Monthly avg \n", sns.pairplot(df2), '\n')
print("Yearly avg \n", sns.pairplot(df3), '\n')
# Out:
# Daily avg
#  <seaborn.axisgrid.PairGrid object at 0x000001CBA792AA00>
#
# Weekly avg
#  <seaborn.axisgrid.PairGrid object at 0x000001CBA7926790>
#
# Monthly avg
#  <seaborn.axisgrid.PairGrid object at 0x000001CBA792AA00>
#
# Yearly avg
#  <seaborn.axisgrid.PairGrid object at 0x000001CBA7926790>

# %%
# lets plot our data for diff time stamps
plt.figure(figsize=(10,6))
plt.plot(df1['Price'])
plt.title(label = 'Weekly Price', fontsize=18)
plt.show();

plt.figure(figsize=(10,6))
plt.plot(df2['Price'])
plt.title(label = 'Monthly Price', fontsize=18)
plt.show();

plt.figure(figsize=(10,6))
plt.plot(df3['Price'])
plt.title(label = 'Yearly Price', fontsize=18)
plt.show();

# %% [markdown]
# Observation: As the time stamp are seperated into different way of counting , week /month /year
# the Plots observe gradually become more gentle curves. Means that when we look at data as year it onyl consider the average of the entire year to a single price point. Hence gentle curve occurs

# %% [markdown]
# **20 Major Ports Avg Price**

# %%
eda(mpa20)
# Out:
# dataframe shape
#  (793, 7)
#
# dataframe types
#  Day                                      object
# Month                                    object
# Year                                      int64
# VLSFO Fuel Oil, IMO 2020 Grade, 0.5%    float64
# Marine Gas Oil                          float64
# Intermdiate Fuel Oil, 180cSt            float64
# Intermdiate Fuel Oil, 380cSt            float64
# dtype: object
#
# dataframe describe
#                Year  VLSFO Fuel Oil, IMO 2020 Grade, 0.5%  Marine Gas Oil  \
# count   793.000000                            611.000000      789.000000
# mean   2020.102144                            480.803601      577.588086
# std       0.879571                            125.896067      128.476151
# min    2019.000000                            210.000000      268.500000
# 25%    2019.000000                            349.500000      460.000000
# 50%    2020.000000                            515.500000      628.000000
# 75%    2021.000000                            563.500000      666.500000
# max    2022.000000                            734.000000      867.500000
#
#        Intermdiate Fuel Oil, 180cSt  Intermdiate Fuel Oil, 380cSt
# count                    284.000000                    789.000000
# mean                     423.794014                    377.968948
# std                       47.988577                     84.699555
# min                      295.000000                    157.500000
# 25%                      390.250000                    323.500000
# 50%                      433.250000                    391.500000
# 75%                      465.500000                    438.000000
# max                      542.500000                    565.500000
#
# missing values
#  Day                                       0
# Month                                     0
# Year                                      0
# VLSFO Fuel Oil, IMO 2020 Grade, 0.5%    182
# Marine Gas Oil                            4
# Intermdiate Fuel Oil, 180cSt            509
# Intermdiate Fuel Oil, 380cSt              4
# dtype: int64
#
# duplicate values
#  0
#
# dataframe columns
#  Index(['Day', 'Month', 'Year', 'VLSFO Fuel Oil, IMO 2020 Grade, 0.5%',
#        'Marine Gas Oil', 'Intermdiate Fuel Oil, 180cSt',
#        'Intermdiate Fuel Oil, 380cSt'],
#       dtype='object')
#
# Day is unique: True
# Month is unique: False
# Year is unique: False
# VLSFO Fuel Oil, IMO 2020 Grade, 0.5% is unique: False
# Marine Gas Oil is unique: False
# Intermdiate Fuel Oil, 180cSt is unique: False
# Intermdiate Fuel Oil, 380cSt is unique: False

# %%
sns.pairplot(mpa20)

# %%
#preparing data set
mpa20.head()
# Out:
#           Day     Month  Year  VLSFO Fuel Oil, IMO 2020 Grade, 0.5%  \
# 0  01/29/2019   January  2019                                   NaN
# 1  01/30/2019   January  2019                                   NaN
# 2  01/31/2019   January  2019                                   NaN
# 3  02/01/2019  February  2019                                   NaN
# 4  02/04/2019  February  2019                                   NaN
#
#    Marine Gas Oil  Intermdiate Fuel Oil, 180cSt  Intermdiate Fuel Oil, 380cSt
# 0           636.5                         429.0                         400.5
# 1           640.5                         436.0                         407.5
# 2           642.5                         439.0                         410.0
# 3           643.5                         440.0                         410.0
# 4           648.5                         438.5                         414.5

# %%
mpa20 = mpa20.rename(columns={'VLSFO Fuel Oil, IMO 2020 Grade, 0.5%': 'Price2'})
mpa20.head()
# Out:
#           Day     Month  Year  Price2  Marine Gas Oil  \
# 0  01/29/2019   January  2019     NaN           636.5
# 1  01/30/2019   January  2019     NaN           640.5
# 2  01/31/2019   January  2019     NaN           642.5
# 3  02/01/2019  February  2019     NaN           643.5
# 4  02/04/2019  February  2019     NaN           648.5
#
#    Intermdiate Fuel Oil, 180cSt  Intermdiate Fuel Oil, 380cSt
# 0                         429.0                         400.5
# 1                         436.0                         407.5
# 2                         439.0                         410.0
# 3                         440.0                         410.0
# 4                         438.5                         414.5

# %%
mpa20['Price2'].value_counts()
# Out:
# 560.5    7
# 340.5    5
# 558.5    5
# 496.0    5
# 455.5    5
#         ..
# 603.5    1
# 588.0    1
# 363.0    1
# 281.0    1
# 577.5    1
# Name: Price2, Length: 400, dtype: int64

# %%
mpa20=mpa20[['Day','Price2']]
mpa20
# Out:
#             Day  Price2
# 0    01/29/2019     NaN
# 1    01/30/2019     NaN
# 2    01/31/2019     NaN
# 3    02/01/2019     NaN
# 4    02/04/2019     NaN
# ..          ...     ...
# 788  02/07/2022   734.0
# 789  02/08/2022     NaN
# 790  02/09/2022     NaN
# 791  02/10/2022     NaN
# 792  02/11/2022     NaN
#
# [793 rows x 2 columns]

# %%
#dropping unwanted column
#droplist = ['Month', 'Year','Marine Gas Oil', 'Intermdiate Fuel Oil, 180cSt',
       #'Intermdiate Fuel Oil, 380cSt']
#mpa20_price.drop(droplist, axis = 1, inplace= True)

# %%
mpa20.shape
# Out:
# (793, 2)

# %%
mpa20.tail(10)
# Out:
#             Day  Price2
# 783  01/31/2022   706.0
# 784  02/01/2022   705.0
# 785  02/02/2022   708.0
# 786  02/03/2022   717.0
# 787  02/04/2022   731.5
# 788  02/07/2022   734.0
# 789  02/08/2022     NaN
# 790  02/09/2022     NaN
# 791  02/10/2022     NaN
# 792  02/11/2022     NaN

# %%
mpa20.rename({'Day': 'Date'}, axis=1, inplace=True)
mpa20.head()
# Out:
#          Date  Price2
# 0  01/29/2019     NaN
# 1  01/30/2019     NaN
# 2  01/31/2019     NaN
# 3  02/01/2019     NaN
# 4  02/04/2019     NaN

# %%
mpa20['Date'] = pd.to_datetime(mpa20['Date'])
mpa20.head()
# Out:
#         Date  Price2
# 0 2019-01-29     NaN
# 1 2019-01-30     NaN
# 2 2019-01-31     NaN
# 3 2019-02-01     NaN
# 4 2019-02-04     NaN

# %%
#setting date to index 
mpa20.index = mpa20.pop('Date')

# %%
mpa20
# Out:
#             Price2
# Date
# 2019-01-29     NaN
# 2019-01-30     NaN
# 2019-01-31     NaN
# 2019-02-01     NaN
# 2019-02-04     NaN
# ...            ...
# 2022-02-07   734.0
# 2022-02-08     NaN
# 2022-02-09     NaN
# 2022-02-10     NaN
# 2022-02-11     NaN
#
# [793 rows x 1 columns]

# %% [markdown]
# ***Rolling mean

# %%
#rolling mean for all 10 days
print("Daily avg \n", df.rolling(10).mean(), '\n')
print("Weekly avg \n", df1.rolling(10).mean(), '\n')
print("Monthly avg \n", df2.rolling(10).mean(), '\n')
print("Yearly avg \n", df3.rolling(10).mean(), '\n')

# %% [markdown]
# ***300 day Moving Average of Price

# %%
plt.figure(figsize=(12,8))
plt.plot(df['Price'], label='Price')
plt.plot(df['Price'].rolling(10).mean(), label='7MA')
plt.plot(df['Price'].rolling(30).mean(), label='30MA')
plt.plot(df['Price'].rolling(300).mean(), label='300MA')
plt.plot(df['Price'].rolling(500).mean(), label='500MA')
plt.legend();

# %%
#lets see Monthly Moving average
plt.figure(figsize=(12,8))
plt.plot(df2['Price'], label='Price')
plt.plot(df2['Price'].rolling(10).mean(), label='7MA')
plt.plot(df2['Price'].rolling(30).mean(), label='30MA')
plt.plot(df2['Price'].rolling(300).mean(), label='300MA')
plt.plot(df2['Price'].rolling(500).mean(), label='500MA')
plt.legend();

# %% [markdown]
# 4. Setting our variables Function, LSTM

# %%
def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = pd.to_datetime(first_date_str)
  last_date  = pd.to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Price'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# %%
#1987-05-25
windowed_df = df_to_windowed_df(df, 
                                '1987-05-25', 
                                '2022-02-07', 
                                n=3)
windowed_df
# Out:
#      Target Date  Target-3  Target-2  Target-1  Target
# 0     1987-05-25     18.63     18.45     18.55   18.60
# 1     1987-05-26     18.45     18.55     18.60   18.63
# 2     1987-05-27     18.55     18.60     18.63   18.60
# 3     1987-05-28     18.60     18.63     18.60   18.60
# 4     1987-05-29     18.63     18.60     18.60   18.58
# ...          ...       ...       ...       ...     ...
# 8807  2022-02-01     90.70     91.47     92.35   90.24
# 8808  2022-02-02     91.47     92.35     90.24   91.43
# 8809  2022-02-03     92.35     90.24     91.43   92.99
# 8810  2022-02-04     90.24     91.43     92.99   96.86
# 8811  2022-02-07     91.43     92.99     96.86   97.28
#
# [8812 rows x 5 columns]

# %% [markdown]
# Target being corresponding Output and Target -3,2,1 is the input that will fed into our model

# %%
def win_df_date_X_y(win_dataframe):
    df_as_np = win_dataframe.to_numpy()
    dates= df_as_np[:,0]
    middle_matrix=df_as_np[:,1:-1]
    X=middle_matrix.reshape((len(dates),middle_matrix.shape[1],1))

    Y=df_as_np[:,-1]
    return dates, X.astype(np.float32),Y.astype(np.float32)

# %%
dates, X, y= win_df_date_X_y(windowed_df)

# %%
dates.shape, X.shape, y.shape
# Out:
# ((8812,), (8812, 3, 1), (8812,))

# %%
q_80 = int(len(dates) *.8)
q_90 =int(len(dates) *.9)

dates_train, X_train, y_train = dates[:q_80],X[:q_80],y[:q_80]
dates_val, X_val, y_val = dates[q_80:q_90],X[q_80:q_90],y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:],X[q_90:],y[q_90:]

# %%
plt.plot(dates_train,y_train)
plt.plot(dates_val,y_val)
plt.plot(dates_test,y_test)

plt.legend(['Train','validation','Test'])

# %% [markdown]
# 4.LSTM Model

# %%
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# %%
model= Sequential([layers.Input((3,1)),
                   layers.LSTM(60),
                   layers.Dense(32,activation ='relu'),
                   layers.Dense(32,activation ='relu'),
                   layers.Dense(1)])
model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])


model.fit(X_train, y_train, validation_data=(X_val,y_val), epochs=100)
# Out:
# Epoch 1/100
# 221/221 [==============================] - 3s 5ms/step - loss: 1024.1494 - mean_absolute_error: 17.4253 - val_loss: 1.5109 - val_mean_absolute_error: 0.9592
# Epoch 2/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.1872 - mean_absolute_error: 0.8494 - val_loss: 3.2544 - val_mean_absolute_error: 1.5181
# Epoch 3/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.8651 - mean_absolute_error: 0.8539 - val_loss: 1.4673 - val_mean_absolute_error: 0.9371
# Epoch 4/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.5950 - mean_absolute_error: 0.7942 - val_loss: 1.3130 - val_mean_absolute_error: 0.8689
# Epoch 5/100
# 221/221 [==============================] - 1s 4ms/step - loss: 1.5442 - mean_absolute_error: 0.8005 - val_loss: 1.9234 - val_mean_absolute_error: 1.0950
# Epoch 6/100
# 221/221 [==============================] - 1s 4ms/step - loss: 1.4734 - mean_absolute_error: 0.7928 - val_loss: 1.3458 - val_mean_absolute_error: 0.8804
# Epoch 7/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.5126 - mean_absolute_error: 0.8101 - val_loss: 1.5733 - val_mean_absolute_error: 0.9860
# Epoch 8/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4031 - mean_absolute_error: 0.7668 - val_loss: 1.6673 - val_mean_absolute_error: 1.0150
# Epoch 9/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.7268 - mean_absolute_error: 0.8614 - val_loss: 1.5933 - val_mean_absolute_error: 0.9945
# Epoch 10/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4104 - mean_absolute_error: 0.7647 - val_loss: 2.1275 - val_mean_absolute_error: 1.1922
# Epoch 11/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4796 - mean_absolute_error: 0.7872 - val_loss: 1.4067 - val_mean_absolute_error: 0.8961
# Epoch 12/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4047 - mean_absolute_error: 0.7725 - val_loss: 1.3826 - val_mean_absolute_error: 0.9048
# Epoch 13/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4096 - mean_absolute_error: 0.7885 - val_loss: 1.3074 - val_mean_absolute_error: 0.8703
# Epoch 14/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.5363 - mean_absolute_error: 0.8177 - val_loss: 1.4593 - val_mean_absolute_error: 0.9437
# Epoch 15/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.6116 - mean_absolute_error: 0.8461 - val_loss: 1.6835 - val_mean_absolute_error: 1.0298
# Epoch 16/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4372 - mean_absolute_error: 0.7947 - val_loss: 2.1158 - val_mean_absolute_error: 1.1793
# Epoch 17/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.5199 - mean_absolute_error: 0.8199 - val_loss: 3.2864 - val_mean_absolute_error: 1.5424
# Epoch 18/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.6665 - mean_absolute_error: 0.8525 - val_loss: 1.3220 - val_mean_absolute_error: 0.8767
# Epoch 19/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.6140 - mean_absolute_error: 0.8359 - val_loss: 1.4962 - val_mean_absolute_error: 0.9544
# Epoch 20/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.5862 - mean_absolute_error: 0.8323 - val_loss: 1.3434 - val_mean_absolute_error: 0.8756
# Epoch 21/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.5059 - mean_absolute_error: 0.7940 - val_loss: 2.1314 - val_mean_absolute_error: 1.1930
# Epoch 22/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4591 - mean_absolute_error: 0.8047 - val_loss: 1.3097 - val_mean_absolute_error: 0.8698
# Epoch 23/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4303 - mean_absolute_error: 0.7873 - val_loss: 2.6928 - val_mean_absolute_error: 1.3685
# Epoch 24/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.5957 - mean_absolute_error: 0.8483 - val_loss: 1.3135 - val_mean_absolute_error: 0.8661
# Epoch 25/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4673 - mean_absolute_error: 0.8022 - val_loss: 1.4095 - val_mean_absolute_error: 0.9263
# Epoch 26/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.5199 - mean_absolute_error: 0.8034 - val_loss: 1.9855 - val_mean_absolute_error: 1.1273
# Epoch 27/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3111 - mean_absolute_error: 0.7340 - val_loss: 1.6131 - val_mean_absolute_error: 0.9907
# Epoch 28/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4635 - mean_absolute_error: 0.8055 - val_loss: 2.4098 - val_mean_absolute_error: 1.2785
# Epoch 29/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.5036 - mean_absolute_error: 0.8099 - val_loss: 1.5187 - val_mean_absolute_error: 0.9631
# Epoch 30/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4857 - mean_absolute_error: 0.8051 - val_loss: 1.9051 - val_mean_absolute_error: 1.1084
# Epoch 31/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4464 - mean_absolute_error: 0.7931 - val_loss: 1.3391 - val_mean_absolute_error: 0.8713
# Epoch 32/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3960 - mean_absolute_error: 0.7851 - val_loss: 2.1928 - val_mean_absolute_error: 1.2122
# Epoch 33/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4775 - mean_absolute_error: 0.7949 - val_loss: 1.8398 - val_mean_absolute_error: 1.0899
# Epoch 34/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4174 - mean_absolute_error: 0.7865 - val_loss: 1.3547 - val_mean_absolute_error: 0.8850
# Epoch 35/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4486 - mean_absolute_error: 0.7974 - val_loss: 1.6008 - val_mean_absolute_error: 1.0020
# Epoch 36/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3983 - mean_absolute_error: 0.7610 - val_loss: 1.7138 - val_mean_absolute_error: 1.0389
# Epoch 37/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4253 - mean_absolute_error: 0.7822 - val_loss: 1.2733 - val_mean_absolute_error: 0.8534
# Epoch 38/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.5149 - mean_absolute_error: 0.8037 - val_loss: 1.3553 - val_mean_absolute_error: 0.8880
# Epoch 39/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4980 - mean_absolute_error: 0.8036 - val_loss: 1.3524 - val_mean_absolute_error: 0.8871
# Epoch 40/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3354 - mean_absolute_error: 0.7482 - val_loss: 1.5878 - val_mean_absolute_error: 0.9977
# Epoch 41/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3925 - mean_absolute_error: 0.7894 - val_loss: 1.3505 - val_mean_absolute_error: 0.8868
# Epoch 42/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4463 - mean_absolute_error: 0.7930 - val_loss: 1.2822 - val_mean_absolute_error: 0.8559
# Epoch 43/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3344 - mean_absolute_error: 0.7408 - val_loss: 1.3713 - val_mean_absolute_error: 0.9073
# Epoch 44/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3783 - mean_absolute_error: 0.7691 - val_loss: 1.2949 - val_mean_absolute_error: 0.8558
# Epoch 45/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4256 - mean_absolute_error: 0.7879 - val_loss: 1.4042 - val_mean_absolute_error: 0.9174
# Epoch 46/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.2743 - mean_absolute_error: 0.7195 - val_loss: 1.2919 - val_mean_absolute_error: 0.8660
# Epoch 47/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3670 - mean_absolute_error: 0.7641 - val_loss: 1.5111 - val_mean_absolute_error: 0.9633
# Epoch 48/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3989 - mean_absolute_error: 0.7654 - val_loss: 1.2761 - val_mean_absolute_error: 0.8566
# Epoch 49/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4757 - mean_absolute_error: 0.7974 - val_loss: 1.3078 - val_mean_absolute_error: 0.8760
# Epoch 50/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.5878 - mean_absolute_error: 0.8249 - val_loss: 1.3940 - val_mean_absolute_error: 0.9124
# Epoch 51/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4609 - mean_absolute_error: 0.7835 - val_loss: 1.4402 - val_mean_absolute_error: 0.9297
# Epoch 52/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3134 - mean_absolute_error: 0.7445 - val_loss: 1.2946 - val_mean_absolute_error: 0.8675
# Epoch 53/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4289 - mean_absolute_error: 0.7700 - val_loss: 1.4635 - val_mean_absolute_error: 0.9413
# Epoch 54/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3098 - mean_absolute_error: 0.7344 - val_loss: 1.3353 - val_mean_absolute_error: 0.8892
# Epoch 55/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3301 - mean_absolute_error: 0.7439 - val_loss: 1.5626 - val_mean_absolute_error: 0.9790
# Epoch 56/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4483 - mean_absolute_error: 0.7908 - val_loss: 2.0576 - val_mean_absolute_error: 1.1618
# Epoch 57/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3312 - mean_absolute_error: 0.7519 - val_loss: 1.4443 - val_mean_absolute_error: 0.9369
# Epoch 58/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3880 - mean_absolute_error: 0.7669 - val_loss: 1.2650 - val_mean_absolute_error: 0.8485
# Epoch 59/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.5021 - mean_absolute_error: 0.8022 - val_loss: 1.2962 - val_mean_absolute_error: 0.8674
# Epoch 60/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4742 - mean_absolute_error: 0.7915 - val_loss: 1.4155 - val_mean_absolute_error: 0.9185
# Epoch 61/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3114 - mean_absolute_error: 0.7281 - val_loss: 1.3021 - val_mean_absolute_error: 0.8726
# Epoch 62/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4546 - mean_absolute_error: 0.7891 - val_loss: 1.5906 - val_mean_absolute_error: 0.9949
# Epoch 63/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.2905 - mean_absolute_error: 0.7271 - val_loss: 1.4875 - val_mean_absolute_error: 0.9529
# Epoch 64/100
# 221/221 [==============================] - 1s 4ms/step - loss: 1.3298 - mean_absolute_error: 0.7449 - val_loss: 1.3481 - val_mean_absolute_error: 0.8915
# Epoch 65/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3533 - mean_absolute_error: 0.7678 - val_loss: 1.3412 - val_mean_absolute_error: 0.8923
# Epoch 66/100
# 221/221 [==============================] - 1s 4ms/step - loss: 1.4742 - mean_absolute_error: 0.7940 - val_loss: 1.8183 - val_mean_absolute_error: 1.0776
# Epoch 67/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4566 - mean_absolute_error: 0.7872 - val_loss: 1.7742 - val_mean_absolute_error: 1.0736
# Epoch 68/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3148 - mean_absolute_error: 0.7412 - val_loss: 1.3491 - val_mean_absolute_error: 0.8942
# Epoch 69/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3654 - mean_absolute_error: 0.7661 - val_loss: 1.2955 - val_mean_absolute_error: 0.8593
# Epoch 70/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3499 - mean_absolute_error: 0.7501 - val_loss: 2.0245 - val_mean_absolute_error: 1.1510
# Epoch 71/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3264 - mean_absolute_error: 0.7451 - val_loss: 1.4276 - val_mean_absolute_error: 0.9260
# Epoch 72/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4348 - mean_absolute_error: 0.7723 - val_loss: 2.3588 - val_mean_absolute_error: 1.2689
# Epoch 73/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3568 - mean_absolute_error: 0.7617 - val_loss: 1.3345 - val_mean_absolute_error: 0.8765
# Epoch 74/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3664 - mean_absolute_error: 0.7571 - val_loss: 1.3030 - val_mean_absolute_error: 0.8686
# Epoch 75/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3582 - mean_absolute_error: 0.7685 - val_loss: 1.2798 - val_mean_absolute_error: 0.8509
# Epoch 76/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3877 - mean_absolute_error: 0.7858 - val_loss: 2.5139 - val_mean_absolute_error: 1.3008
# Epoch 77/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4401 - mean_absolute_error: 0.7895 - val_loss: 1.3805 - val_mean_absolute_error: 0.9049
# Epoch 78/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.6756 - mean_absolute_error: 0.8385 - val_loss: 1.3476 - val_mean_absolute_error: 0.8960
# Epoch 79/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3575 - mean_absolute_error: 0.7492 - val_loss: 1.3874 - val_mean_absolute_error: 0.9120
# Epoch 80/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4287 - mean_absolute_error: 0.7757 - val_loss: 1.3464 - val_mean_absolute_error: 0.8824
# Epoch 81/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3363 - mean_absolute_error: 0.7503 - val_loss: 1.4617 - val_mean_absolute_error: 0.9377
# Epoch 82/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3841 - mean_absolute_error: 0.7663 - val_loss: 2.0043 - val_mean_absolute_error: 1.1459
# Epoch 83/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.4862 - mean_absolute_error: 0.8002 - val_loss: 1.5896 - val_mean_absolute_error: 0.9952
# Epoch 84/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3666 - mean_absolute_error: 0.7438 - val_loss: 1.4855 - val_mean_absolute_error: 0.9434
# Epoch 85/100
# 221/221 [==============================] - 1s 4ms/step - loss: 1.2690 - mean_absolute_error: 0.7196 - val_loss: 1.2692 - val_mean_absolute_error: 0.8546
# Epoch 86/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3262 - mean_absolute_error: 0.7509 - val_loss: 1.4360 - val_mean_absolute_error: 0.9241
# Epoch 87/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3604 - mean_absolute_error: 0.7577 - val_loss: 1.3004 - val_mean_absolute_error: 0.8639
# Epoch 88/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3479 - mean_absolute_error: 0.7472 - val_loss: 1.3482 - val_mean_absolute_error: 0.8920
# Epoch 89/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.2691 - mean_absolute_error: 0.7218 - val_loss: 1.3757 - val_mean_absolute_error: 0.9076
# Epoch 90/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3930 - mean_absolute_error: 0.7539 - val_loss: 1.4154 - val_mean_absolute_error: 0.9136
# Epoch 91/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3269 - mean_absolute_error: 0.7376 - val_loss: 1.9790 - val_mean_absolute_error: 1.1393
# Epoch 92/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3164 - mean_absolute_error: 0.7364 - val_loss: 1.2988 - val_mean_absolute_error: 0.8702
# Epoch 93/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3379 - mean_absolute_error: 0.7435 - val_loss: 1.2788 - val_mean_absolute_error: 0.8593
# Epoch 94/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3099 - mean_absolute_error: 0.7380 - val_loss: 1.9441 - val_mean_absolute_error: 1.1318
# Epoch 95/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.5099 - mean_absolute_error: 0.8072 - val_loss: 1.3097 - val_mean_absolute_error: 0.8655
# Epoch 96/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3214 - mean_absolute_error: 0.7326 - val_loss: 1.7697 - val_mean_absolute_error: 1.0663
# Epoch 97/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3785 - mean_absolute_error: 0.7600 - val_loss: 1.3124 - val_mean_absolute_error: 0.8763
# Epoch 98/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.2761 - mean_absolute_error: 0.7148 - val_loss: 1.3889 - val_mean_absolute_error: 0.9028
# Epoch 99/100
# 221/221 [==============================] - 1s 3ms/step - loss: 1.3375 - mean_absolute_error: 0.7467 - val_loss: 1.3331 - val_mean_absolute_error: 0.8851
# Epoch 100/100
# 221/221 [==============================] - 1s 4ms/step - loss: 1.3108 - mean_absolute_error: 0.7317 - val_loss: 1.5712 - val_mean_absolute_error: 0.9747

# %% [markdown]
# mean_absolute_error this is important

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])

# %% [markdown]
# END

# %% [markdown]
# 3.Stationarity of Data

# %%
#Using Pacf to determine what order have best corr 
import pmdarima as pm
from pmdarima import datasets

y = df['Price']
pm.plot_pacf(y)

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adftest = adfuller(df['Price'], autolag= 'AIC')

# %%
print(' ADF:',adftest[0])
print('P-value:',adftest[1])
print('Num of lags:',adftest[2])
print('Num of Observation used for ADF Regression & Critical value Calculation:',adftest[3])
print('Critical value:')
for key, val in adftest[4].items():
    print('\t' ,key, ":", val)
# Out:
#  ADF: -1.8997715641726658
# P-value: 0.33216858177501096
# Num of lags: 35
# Num of Observation used for ADF Regression & Critical value Calculation: 8779
# Critical value:
# 	 1% : -3.43109509774388
# 	 5% : -2.8618692838372026
# 	 10% : -2.566945272806482

# %% [markdown]
# Observation: p-value = 0.3 < 0.5, means dataset is somewhat stationary

# %%
#import ADF
from pmdarima.arima.stationarity import ADFTest

# Augmented Dickey-Fuller test 
adf_test = ADFTest(alpha = 0.05)
adf_test.should_diff(df['Price'])
# Out:
# (0.2792344912779806, True)

# %% [markdown]
# Since the ADF test show 'True' meaning dataset should do differencing

# %% [markdown]
# Estimating d parameter more directly

# %%
from pmdarima.arima.utils import ndiffs
n_kpss = ndiffs(y, test='kpss')  # -> 0
n_kpss #integration order of the seasonal process=1
# Out:
# 1

# %% [markdown]
# Applying Differencing to Data

# %%
df_diff = df.diff(10)
df_diff.tail()
# Out:
#             Price
# Date
# 2022-02-01   1.41
# 2022-02-02   1.79
# 2022-02-03   3.24
# 2022-02-04   7.11
# 2022-02-07   9.54

# %%
df_pct = df.pct_change(10)
df_pct.tail()
# Out:
#                Price
# Date
# 2022-02-01  0.015873
# 2022-02-02  0.019969
# 2022-02-03  0.036100
# 2022-02-04  0.079220
# 2022-02-07  0.108730

# %%
#comparing plots
fig, axes = plt.subplots(nrows=3, figsize=(15,12))
axes[0].plot(df['Price'], label='Price')
axes[0].legend()
axes[1].plot(df_diff, label='Diff')
axes[1].legend()
axes[2].plot(df_pct, label='Pct Diff')
axes[2].legend()

# %%
# shifting for stationarity.
df_shift = df.shift(5)

# %%
today = df[['Price']].pct_change()

# %%
today.head()

# %%
yesterday = today[['Price']].shift(2)
yesterday.columns=['Yesterday Price']
yesterday.head()

# %%
today = today.join(yesterday).dropna()
today.head()

# %%
today['Price'] = (today['Price'] >=0).astype(int)
today.head()

# %%
today = today[['Price', 'Yesterday Price']]
today.head()

# %%
# def function to plot data
def plot_series(df, col, title='Title', xlab=None, ylab=None, steps=1):
    
    plt.figure(figsize=(17,8))
               
    plt.plot(df[col])
        
    # Generate title and labels.
    plt.title(title, fontsize=25)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    
    # Enlarge tick marks.
    plt.yticks(fontsize=18)
    plt.xticks(df.index[0::steps], fontsize=18);

# %%
# Generate a time plot of our data.
plot_series(df, 'Price', title = "Price of brent Crude", steps=1000)

# %%
# Generate a time plot of our data.
plot_series(df.resample('A').mean(), col='Price', title='Price of brent Crude', steps=4000)

# %% [markdown]
# Modeling

# %%
# Create train-test split.
y_train = df['2000': '2007']

# %%
y_test = df['2008']
# Out:
# <ipython-input-51-78ab19067399>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   y_test = df['2008']

# %%
print(df.shape)
print(y_train.shape,y_test.shape)
# Out:
# (8815, 1)
# (2046, 1) (253, 1)

# %%
y_test.head()
# Out:
#             Price
# Date
# 2008-01-02  97.01
# 2008-01-03  98.45
# 2008-01-04  96.87
# 2008-01-07  94.19
# 2008-01-08  96.37

# %%
df.tail()
# Out:
#             Price
# Date
# 2022-02-01  90.24
# 2022-02-02  91.43
# 2022-02-03  92.99
# 2022-02-04  96.86
# 2022-02-07  97.28

# %% [markdown]
# Observation: we will be using 2000 to 2007 as train , 2008 as test data

# %%
#more imports
from sklearn.model_selection import train_test_split
import pmdarima as pm

# %% [markdown]
# - Since the ADF test show True means data should do differencing

# %%
# Fit Auto ARIMA
arima_model = pm.AutoARIMA(start_p=0, max_p=4, 
                           d=None,    # find optimum value of d automatically
                           start_q=0, max_q=4,
                           start_P=0, max_P=4,
                           D=None,
                           start_Q=0, max_Q=4,
                           m=12, # For monthly data since the pattern repeats every 12 months
                           seasonal=True,
                           trace=True, # Print values for each fit in the grid search
                           random=True,
                           #random_state=20,
                           n_fits=50
                          )

arima_model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=5546.136, Time=0.33 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=5548.524, Time=0.39 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=5548.614, Time=0.46 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=5546.836, Time=0.05 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=5546.554, Time=0.32 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=5546.644, Time=0.30 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=5548.051, Time=0.99 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=5548.096, Time=0.20 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=5548.098, Time=0.28 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=5542.902, Time=1.00 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=5549.737, Time=1.24 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=5549.818, Time=1.19 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=5551.305, Time=1.86 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=5550.518, Time=0.68 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=5550.523, Time=0.38 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=5548.832, Time=0.25 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=5548.795, Time=0.23 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=5552.509, Time=0.78 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=5543.626, Time=0.49 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[12] intercept
# Total fit time: 11.463 seconds
# AutoARIMA(m=12, max_P=4, max_Q=4, max_p=4, max_q=4, n_fits=50, random=True,
#           start_P=0, start_Q=0, start_p=0, start_q=0, trace=True)

# %%
arima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2046
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -2767.451
# Date:                Tue, 05 Apr 2022   AIC                           5542.902
# Time:                        07:30:11   BIC                           5565.395
# Sample:                             0   HQIC                          5551.152
#                                - 2046
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0680      0.041      1.646      0.100      -0.013       0.149
# ar.L1         -0.9954      0.007   -150.194      0.000      -1.008      -0.982
# ma.L1          0.9887      0.009    112.205      0.000       0.971       1.006
# sigma2         0.8769      0.019     45.993      0.000       0.839       0.914
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):               409.37
# Prob(Q):                              0.78   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.06   Skew:                            -0.08
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# Making prediction on Test set

# %%
y_pred = arima_model.predict(n_periods = len(y_test))

# Plot data.
plt.figure(figsize=(30,15))

# Plot training data.
plt.plot(y_train, color='blue', label='y_train')

# Plot testing data.
plt.plot(y_test, color='orange', label='y_test')

# Plot predicted test values.
plt.plot(y_test.index, y_pred, color='green', label='y_pred')

plt.title(label = 'ARIMA predictions', fontsize=16)
plt.legend();

# %% [markdown]
# advance time series

# %%
#Weekly 
y_train1 = df1['1987': '2007']
y_test1 = y1['2008':]

print(y_train1.tail())
print(y_test1.head())
print(y_train1.shape)
print(y_test1.shape)

# %%
# Fit Auto ARIMA
arima_model2 = pm.AutoARIMA(start_p=0, max_p=10, 
                           d=None,    # find optimum value of d automatically
                           start_q=0, max_q=10,
                           start_P=0, max_P=10,
                           D=None,
                           start_Q=0, max_Q=10,
                           m=12, # For monthly data since the pattern repeats every 12 months
                           seasonal=True,
                           trace=True, # Print values for each fit in the grid search
                           random=True,
                           #random_state=20,
                           n_fits=50
                          )

arima_model.fit(y_train1)

# %%
# Create an helper function to help make predictions and plot the results
def plot_forecast(y_train1, y_test1, arima_model2, X_test=None):
    # Generate len(y_test) number of predictions
    y_pred1 = arima_model.predict(n_periods = len(y_test1), X=X_test)

    # Plot data.
    plt.figure(figsize=(10,6))

    # Plot training data.
    plt.plot(y_train1, color='blue', label='y_train')

    # Plot testing data.
    plt.plot(y_test1, color='orange', label='y_test')

    # Plot predicted test values.
    plt.plot(y_test1.index, y_pred1, color='green', label='y_pred')
    
    # Find the MAPE of the predictions
    # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_percentage_error.html
    mape = mean_absolute_percentage_error(y_test1, y_pred1)

    plt.title(label = f'Price Predictions\n MAPE: {mape:.2f}', fontsize=16)
    plt.legend();

# %%
plot_forecast(y_train1, y_test1, arima_model2)

# %%
#SARIMA
from statsmodels.graphics.tsaplots import plot_acf

# %%
# Generate autocorrelation plot on training data.
plot_acf(y_train1.diff().dropna());

# %%
# Fit Auto ARIMA
arima_model3 = pm.AutoARIMA(start_p=0, max_p=10, 
                           d=None,    # find optimum value of d automatically
                           start_q=0, max_q=10,
                           start_P=0, max_P=10,
                           D=None,    # find optimum value of D automatically
                           start_Q=0, max_Q=50,
                           m=3, # Since the peak occurs every 3 months!
                           seasonal=True,
                           trace=True, # Print values for each fit in the grid search
                           random=True,
                           random_state=20,
                           n_fits=50
                          )

arima_model.fit(y_train1)

# %%
# Our best model is ARIMA(p=2,d=0,q=0)(P=0,D=1,Q=5)[S=3]
plot_forecast(y_train1, y_test1, arima_model2)

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
y_test.mean()

# %%
rmse=sqrt(mean_squared_error(y_test,y_pred))

# %% [markdown]
# LSTM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=20,10
from keras.models import Sequential
from keras.layers import LSTM,Dropout,Dense
from sklearn.preprocessing import MinMaxScaler

# %%
import tensorflow as tf

# %%
plt.figure(figsize=(16,8))
plt.plot(df["Price"],label='Price history')

# %%
data=df.sort_index(ascending=True,axis=0)
data.head()
# Out:
#             Price
# Date
# 1987-05-20  18.63
# 1987-05-21  18.45
# 1987-05-22  18.55
# 1987-05-25  18.60
# 1987-05-26  18.63

# %%
#new_dataset=pd.DataFrame(index=range(0,len(df)),columns=['Date','Price'])
#for i in range(0,len(data)):
  #  new_dataset["Date"][i]=data['Date'][i]
  #  new_dataset["Price"][i]=data["Price"][i]

# %%
new_dataset=data.copy()

# %%
new_dataset.head()
# Out:
#             Price
# Date
# 1987-05-20  18.63
# 1987-05-21  18.45
# 1987-05-22  18.55
# 1987-05-25  18.60
# 1987-05-26  18.63

# %%
data.reset_index(inplace= True)
data.head()
# Out:
#         Date  Price
# 0 1987-05-20  18.63
# 1 1987-05-21  18.45
# 2 1987-05-22  18.55
# 3 1987-05-25  18.60
# 4 1987-05-26  18.63

# %%
data.drop(columns=['index'],inplace=True)

# %%
data.head()
# Out:
#         Date  Price
# 0 1987-05-20  18.63
# 1 1987-05-21  18.45
# 2 1987-05-22  18.55
# 3 1987-05-25  18.60
# 4 1987-05-26  18.63

# %%
data[data['Date']< '2021-01-01']
#2009 >
# Out:
#            Date  Price
# 0    1987-05-20  18.63
# 1    1987-05-21  18.45
# 2    1987-05-22  18.55
# 3    1987-05-25  18.60
# 4    1987-05-26  18.63
# ...         ...    ...
# 8531 2020-12-24  50.88
# 8532 2020-12-28  50.88
# 8533 2020-12-29  50.44
# 8534 2020-12-30  50.74
# 8535 2020-12-31  51.22
#
# [8536 rows x 2 columns]

# %%
scaler=MinMaxScaler(feature_range=(0,1))
final_dataset=new_dataset.values #y
#2009
#train_data=final_dataset[0:5245,:]
#valid_data=final_dataset[5246:5499,:]
train_data=final_dataset[0:7771,:] #2018
valid_data=final_dataset[7772:8536,:] #2021

#new_dataset.drop("Date",axis=1,inplace=True)
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(final_dataset)

x_train_data,y_train_data=[],[]

for i in range(60,len(train_data)):
    x_train_data.append(scaled_data[i-60:i,0])
    y_train_data.append(scaled_data[i,0])
    
x_train_data,y_train_data=np.array(x_train_data),np.array(y_train_data)

x_train_data=np.reshape(x_train_data,(x_train_data.shape[0],x_train_data.shape[1],1))

# %%
new_dataset.tail()
# Out:
#             Price
# Date
# 2022-02-01  90.24
# 2022-02-02  91.43
# 2022-02-03  92.99
# 2022-02-04  96.86
# 2022-02-07  97.28

# %%
new_dataset= new_dataset.iloc[:8536,:]

# %%
lstm_model=Sequential()
lstm_model.add(LSTM(units=50,return_sequences=True,input_shape=(x_train_data.shape[1],1)))
lstm_model.add(LSTM(units=50))
lstm_model.add(Dense(1))

inputs_data=new_dataset[len(new_dataset)-len(valid_data)-60:].values
inputs_data=inputs_data.reshape(-1,1)
inputs_data=scaler.transform(inputs_data)

lstm_model.compile(loss='mean_squared_error',optimizer='adam')
lstm_model.fit(x_train_data,y_train_data,epochs=1,batch_size=1,verbose=2)
# Out:
# 7711/7711 - 153s - loss: 5.2013e-04 - 153s/epoch - 20ms/step

# %%
X_test=[]
for i in range(60,inputs_data.shape[0]):
    X_test.append(inputs_data[i-60:i,0])
X_test=np.array(X_test)

X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
predicted_closing_price=lstm_model.predict(X_test)
predicted_closing_price=scaler.inverse_transform(predicted_closing_price)

# %%
lstm_model.save("saved_model.h5")

# %%
train_data=new_dataset[:7771]
valid_data=new_dataset[7772:8536]
valid_data['Predictions']=predicted_closing_price
plt.plot(train_data["Price"])
plt.plot(valid_data[['Price',"Predictions"]])
plt.legend(['Price','Predictions'])
# Out:
# <ipython-input-74-e74af82c7a3d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_data['Predictions']=predicted_closing_price
