# %% [markdown]
# Oil markets have been seen as something close to perfect competition, impenetrable and prone to exogenous shocks, political, economic or other.
#
# Therefore companies, bunker trading firms can secure market competitiveness by making successful fuel oil purchases with cost efficiency.
#
# My Goal is to build a Time Series model to predict bunker price using Brent Crude. 20 Major Ports Bunker price Average and Brent Crude Data would be used. We will look at VLSFO Fuel Oil, IMO 2020 Grade, 0.5% Since is the newer product available in the market.

# %% [markdown]
# - Avg 20 major Port Bunker price
# - Brent Crude Price
#
# - 20 Major Ports:
#    - Busan, Colombo, Durban, Fujairah, Gibraltar, Hong Kong, Houston, Istanbul, LA/Long Beach, Las Palmas, Mumbai, New York, Panama, Piraeus, Rotterdam, Santos, Shanghai, Singapore, St Petersburg, Tokyo

# %% [markdown]
# Imports

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
# %config InlineBackend.figure_format = 'retina'
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
from datetime import datetime
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# Import Data

# %%
#dated 1987 to 2022
df= pd.read_csv('./data/Daily_Brent_Crude_Oil_Spot_Prices2022.csv')

#new blend VLSFO 0.5% (dated 2020 to 2022 Q1)
mpa20_price= pd.read_csv('./data/Daily_Bunker_Fuel_Prices.csv')

# %% [markdown]
# Apply Function for EDA of Data

# %%
# Def function for EDA on dataframe
def eda(dataframe):
    print("dataframe shape \n", dataframe.shape, '\n')
    print("dataframe types \n", dataframe.dtypes, '\n')
    print("dataframe describe \n", dataframe.describe(), '\n')
    print("dataframe describe \n", dataframe.describe(exclude=np.number).T, '\n')
    print("missing values \n", dataframe.isnull().sum(), '\n')
    print("duplicate values \n", dataframe.duplicated().sum(), '\n')
    print("dataframe columns \n", dataframe.columns, '\n')
    
#check if column is unique
    for i in dataframe.columns:
        print('{} is unique: {}'.format(i, dataframe[i].is_unique))

# %%
eda(df)
# Out:
# dataframe shape
#  (8815, 2)
#
# dataframe types
#  Date      object
# Price    float64
# dtype: object
#
# dataframe describe
#               Price
# count  8815.000000
# mean     47.157345
# std      32.052617
# min       9.100000
# 25%      18.950000
# 50%      35.720000
# 75%      68.415000
# max     143.950000
#
# dataframe describe
#       count unique         top freq
# Date  8815   8815  11/25/1993    1
#
# missing values
#  Date     0
# Price    0
# dtype: int64
#
# duplicate values
#  0
#
# dataframe columns
#  Index(['Date', 'Price'], dtype='object')
#
# Date is unique: True
# Price is unique: False

# %%
eda(mpa20_price)
# Out:
# dataframe shape
#  (793, 7)
#
# dataframe types
#  Day                                      object
# Month                                    object
# Year                                      int64
# VLSFO Fuel Oil, IMO 2020 Grade, 0.5%    float64
# Marine Gas Oil                          float64
# Intermdiate Fuel Oil, 180cSt            float64
# Intermdiate Fuel Oil, 380cSt            float64
# dtype: object
#
# dataframe describe
#                Year  VLSFO Fuel Oil, IMO 2020 Grade, 0.5%  Marine Gas Oil  \
# count   793.000000                            611.000000      789.000000
# mean   2020.102144                            480.803601      577.588086
# std       0.879571                            125.896067      128.476151
# min    2019.000000                            210.000000      268.500000
# 25%    2019.000000                            349.500000      460.000000
# 50%    2020.000000                            515.500000      628.000000
# 75%    2021.000000                            563.500000      666.500000
# max    2022.000000                            734.000000      867.500000
#
#        Intermdiate Fuel Oil, 180cSt  Intermdiate Fuel Oil, 380cSt
# count                    284.000000                    789.000000
# mean                     423.794014                    377.968948
# std                       47.988577                     84.699555
# min                      295.000000                    157.500000
# 25%                      390.250000                    323.500000
# 50%                      433.250000                    391.500000
# 75%                      465.500000                    438.000000
# max                      542.500000                    565.500000
#
# dataframe describe
#        count unique         top freq
# Day     793    793  09/12/2019    1
# Month   793     12    February   69
#
# missing values
#  Day                                       0
# Month                                     0
# Year                                      0
# VLSFO Fuel Oil, IMO 2020 Grade, 0.5%    182
# Marine Gas Oil                            4
# Intermdiate Fuel Oil, 180cSt            509
# Intermdiate Fuel Oil, 380cSt              4
# dtype: int64
#
# duplicate values
#  0
#
# dataframe columns
#  Index(['Day', 'Month', 'Year', 'VLSFO Fuel Oil, IMO 2020 Grade, 0.5%',
#        'Marine Gas Oil', 'Intermdiate Fuel Oil, 180cSt',
#        'Intermdiate Fuel Oil, 380cSt'],
#       dtype='object')
#
# Day is unique: True
# Month is unique: False
# Year is unique: False
# VLSFO Fuel Oil, IMO 2020 Grade, 0.5% is unique: False
# Marine Gas Oil is unique: False
# Intermdiate Fuel Oil, 180cSt is unique: False
# Intermdiate Fuel Oil, 380cSt is unique: False

# %%
sns.pairplot(df)

# %%
sns.pairplot(mpa20_price)

# %% [markdown]
# **Checking Data Values**
# - Brent Crude

# %%
df.head()
# Out:
#          Date  Price
# 0  05/20/1987  18.63
# 1  05/21/1987  18.45
# 2  05/22/1987  18.55
# 3  05/25/1987  18.60
# 4  05/26/1987  18.63

# %%
df['Price'].value_counts()
# Out:
# 18.48    26
# 18.15    22
# 16.85    20
# 18.63    18
# 17.00    18
#          ..
# 45.54     1
# 68.53     1
# 28.83     1
# 18.76     1
# 55.06     1
# Name: Price, Length: 4867, dtype: int64

# %%
#Change date column to be datetime dtype
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date  Price
# 0 1987-05-20  18.63
# 1 1987-05-21  18.45
# 2 1987-05-22  18.55
# 3 1987-05-25  18.60
# 4 1987-05-26  18.63

# %%
df.dtypes
# Out:
# Date     datetime64[ns]
# Price           float64
# dtype: object

# %%
#Sorting to check for Missing values
df['Date'].sort_values()
# Out:
# 0      1987-05-20
# 1      1987-05-21
# 2      1987-05-22
# 3      1987-05-25
# 4      1987-05-26
#           ...
# 8810   2022-02-01
# 8811   2022-02-02
# 8812   2022-02-03
# 8813   2022-02-04
# 8814   2022-02-07
# Name: Date, Length: 8815, dtype: datetime64[ns]

# %% [markdown]
# df data dated from 1987/5/20 to 2022/2/7

# %%
#setting date to index 
df = df.set_index('Date')

print(df.shape)
df.head()
# Out:
# (8815, 1)
#             Price
# Date
# 1987-05-20  18.63
# 1987-05-21  18.45
# 1987-05-22  18.55
# 1987-05-25  18.60
# 1987-05-26  18.63

# %%
#sort by data 
df = df.sort_index()

print(df.shape)
df.head()
# Out:
# (8815, 1)
#             Price
# Date
# 1987-05-20  18.63
# 1987-05-21  18.45
# 1987-05-22  18.55
# 1987-05-25  18.60
# 1987-05-26  18.63

# %% [markdown]
# - 20 Major Ports Avg Price

# %%
#preparing data set
mpa20_price.head()
# Out:
#           Day     Month  Year  VLSFO Fuel Oil, IMO 2020 Grade, 0.5%  \
# 0  01/29/2019   January  2019                                   NaN
# 1  01/30/2019   January  2019                                   NaN
# 2  01/31/2019   January  2019                                   NaN
# 3  02/01/2019  February  2019                                   NaN
# 4  02/04/2019  February  2019                                   NaN
#
#    Marine Gas Oil  Intermdiate Fuel Oil, 180cSt  Intermdiate Fuel Oil, 380cSt
# 0           636.5                         429.0                         400.5
# 1           640.5                         436.0                         407.5
# 2           642.5                         439.0                         410.0
# 3           643.5                         440.0                         410.0
# 4           648.5                         438.5                         414.5

# %%
mpa20_price = mpa20_price.rename(columns={'VLSFO Fuel Oil, IMO 2020 Grade, 0.5%': 'VLSFO'})
mpa20_price.head()
# Out:
#           Day     Month  Year  VLSFO  Marine Gas Oil  \
# 0  01/29/2019   January  2019    NaN           636.5
# 1  01/30/2019   January  2019    NaN           640.5
# 2  01/31/2019   January  2019    NaN           642.5
# 3  02/01/2019  February  2019    NaN           643.5
# 4  02/04/2019  February  2019    NaN           648.5
#
#    Intermdiate Fuel Oil, 180cSt  Intermdiate Fuel Oil, 380cSt
# 0                         429.0                         400.5
# 1                         436.0                         407.5
# 2                         439.0                         410.0
# 3                         440.0                         410.0
# 4                         438.5                         414.5

# %%
mpa20_price['VLSFO'].value_counts()
# Out:
# 560.5    7
# 340.5    5
# 558.5    5
# 496.0    5
# 455.5    5
#         ..
# 603.5    1
# 588.0    1
# 363.0    1
# 281.0    1
# 577.5    1
# Name: VLSFO, Length: 400, dtype: int64

# %%
#dropping unwanted column
droplist = ['Month', 'Year','Marine Gas Oil', 'Intermdiate Fuel Oil, 180cSt',
       'Intermdiate Fuel Oil, 380cSt']
mpa20_price.drop(droplist, axis = 1, inplace= True)

# %%
mpa20_price.head()
# Out:
#           Day  VLSFO
# 0  01/29/2019    NaN
# 1  01/30/2019    NaN
# 2  01/31/2019    NaN
# 3  02/01/2019    NaN
# 4  02/04/2019    NaN

# %%
mpa20_price.tail(10)
# Out:
#             Day  VLSFO
# 783  01/31/2022  706.0
# 784  02/01/2022  705.0
# 785  02/02/2022  708.0
# 786  02/03/2022  717.0
# 787  02/04/2022  731.5
# 788  02/07/2022  734.0
# 789  02/08/2022    NaN
# 790  02/09/2022    NaN
# 791  02/10/2022    NaN
# 792  02/11/2022    NaN

# %%
mpa20_price.rename({'Day': 'Date'}, axis=1, inplace=True)
mpa20_price.head()
# Out:
#          Date  VLSFO
# 0  01/29/2019    NaN
# 1  01/30/2019    NaN
# 2  01/31/2019    NaN
# 3  02/01/2019    NaN
# 4  02/04/2019    NaN

# %%
#setting date to index 
mpa20_price = mpa20_price.set_index('Date')

print(mpa20_price.shape)
mpa20_price.head()
# Out:
# (793, 1)
#             VLSFO
# Date
# 01/29/2019    NaN
# 01/30/2019    NaN
# 01/31/2019    NaN
# 02/01/2019    NaN
# 02/04/2019    NaN

# %%
#sort by data
mpa20_price = mpa20_price.sort_index()

print(mpa20_price.shape)
mpa20_price.head()
# Out:
# (793, 1)
#             VLSFO
# Date
# 01/01/2020  672.0
# 01/01/2021  421.0
# 01/02/2020  677.5
# 01/03/2020  684.0
# 01/03/2022  628.5

# %% [markdown]
# **Filtering by dates**
# - Brent Crude

# %%
#filter by year
df.loc['2020']
# Out:
#             Price
# Date
# 2020-01-02  67.05
# 2020-01-03  69.08
# 2020-01-06  70.25
# 2020-01-07  68.74
# 2020-01-08  67.31
# ...           ...
# 2020-12-24  50.88
# 2020-12-28  50.88
# 2020-12-29  50.44
# 2020-12-30  50.74
# 2020-12-31  51.22
#
# [255 rows x 1 columns]

# %%
#filter by month Feb
df.loc['2020-06']
# Out:
#             Price
# Date
# 2020-06-01  36.74
# 2020-06-02  37.72
# 2020-06-03  37.98
# 2020-06-04  38.41
# 2020-06-05  41.00
# 2020-06-08  39.66
# 2020-06-09  40.45
# 2020-06-10  41.18
# 2020-06-11  37.76
# 2020-06-12  38.54
# 2020-06-15  39.44
# 2020-06-16  40.75
# 2020-06-17  40.47
# 2020-06-18  41.75
# 2020-06-19  42.33
# 2020-06-22  43.20
# 2020-06-23  42.72
# 2020-06-24  40.40
# 2020-06-25  41.18
# 2020-06-26  40.97
# 2020-06-29  41.58
# 2020-06-30  41.64

# %%
#month average
df.resample('M').mean()
# Out:
#                 Price
# Date
# 1987-05-31  18.580000
# 1987-06-30  18.860476
# 1987-07-31  19.856522
# 1987-08-31  18.979524
# 1987-09-30  18.313182
# ...               ...
# 2021-10-31  83.538095
# 2021-11-30  81.050000
# 2021-12-31  74.170476
# 2022-01-31  86.505238
# 2022-02-28  93.760000
#
# [418 rows x 1 columns]

# %%
# week average
df.resample('W').mean()
# Out:
#                 Price
# Date
# 1987-05-24  18.543333
# 1987-05-31  18.602000
# 1987-06-07  18.702000
# 1987-06-14  18.754000
# 1987-06-21  19.007500
# ...               ...
# 2022-01-16  85.068000
# 2022-01-23  89.158000
# 2022-01-30  90.124000
# 2022-02-06  92.774000
# 2022-02-13  97.280000
#
# [1813 rows x 1 columns]

# %%
df.resample('Y').mean()
# Out:
#                  Price
# Date
# 1987-12-31   18.525813
# 1988-12-31   14.905412
# 1989-12-31   18.228228
# 1990-12-31   23.761445
# 1991-12-31   20.041128
# 1992-12-31   19.319728
# 1993-12-31   17.013413
# 1994-12-31   15.856389
# 1995-12-31   17.015850
# 1996-12-31   20.639803
# 1997-12-31   19.108508
# 1998-12-31   12.758103
# 1999-12-31   17.901566
# 2000-12-31   28.660672
# 2001-12-31   24.455720
# 2002-12-31   24.993255
# 2003-12-31   28.850814
# 2004-12-31   38.259693
# 2005-12-31   54.574553
# 2006-12-31   65.161765
# 2007-12-31   72.441160
# 2008-12-31   96.944348
# 2009-12-31   61.738770
# 2010-12-31   79.609444
# 2011-12-31  111.264274
# 2012-12-31  111.570683
# 2013-12-31  108.555000
# 2014-12-31   98.969606
# 2015-12-31   52.316549
# 2016-12-31   43.638000
# 2017-12-31   54.124805
# 2018-12-31   71.335000
# 2019-12-31   64.300623
# 2020-12-31   41.957255
# 2021-12-31   70.855336
# 2022-12-31   87.900385

# %% [markdown]
# Observation on rolling mean

# %%
#rolling mean for 10 days
df.rolling(10).mean()
# Out:
#              Price
# Date
# 1987-05-20     NaN
# 1987-05-21     NaN
# 1987-05-22     NaN
# 1987-05-25     NaN
# 1987-05-26     NaN
# ...            ...
# 2022-02-01  90.235
# 2022-02-02  90.414
# 2022-02-03  90.738
# 2022-02-04  91.449
# 2022-02-07  92.403
#
# [8815 rows x 1 columns]

# %%
#look at data on monthly to weekly basis . find whats the different

# %%
# plot or visualised out monthly and weekly data compare among 3 monthly weekly and daily , more desireable results .... visualisation .

# %%
#linear previous price, shift by one day/ month

# %%
# with 20 mpa data as other variable to plot linear regression and see corelation btw crd oil and mpa

# %%
# apply arima model, with some additional factor or hope it work with some poor result also ok

# %%
#conclusion some benefit

# %% [markdown]
# The 300 day Moving Average of Price

# %%
plt.figure(figsize=(12,8))
plt.plot(df['Price'], label='Price')
plt.plot(df['Price'].rolling(10).mean(), label='7MA')
plt.plot(df['Price'].rolling(30).mean(), label='30MA')
plt.plot(df['Price'].rolling(300).mean(), label='300MA')
plt.plot(df['Price'].rolling(500).mean(), label='500MA')
plt.legend();

# %%
#2000 to 2008

# %%
# price change or T1 and T2, T being specific Time or by percantage pct_change()
df.head()
# Out:
#             Price
# Date
# 1987-05-20  18.63
# 1987-05-21  18.45
# 1987-05-22  18.55
# 1987-05-25  18.60
# 1987-05-26  18.63

# %%
df.diff(10)
# Out:
#             Price
# Date
# 1987-05-20    NaN
# 1987-05-21    NaN
# 1987-05-22    NaN
# 1987-05-25    NaN
# 1987-05-26    NaN
# ...           ...
# 2022-02-01   1.41
# 2022-02-02   1.79
# 2022-02-03   3.24
# 2022-02-04   7.11
# 2022-02-07   9.54
#
# [8815 rows x 1 columns]

# %%
df.pct_change(10)
# Out:
#                Price
# Date
# 1987-05-20       NaN
# 1987-05-21       NaN
# 1987-05-22       NaN
# 1987-05-25       NaN
# 1987-05-26       NaN
# ...              ...
# 2022-02-01  0.015873
# 2022-02-02  0.019969
# 2022-02-03  0.036100
# 2022-02-04  0.079220
# 2022-02-07  0.108730
#
# [8815 rows x 1 columns]

# %%
fig, axes = plt.subplots(nrows=3, figsize=(15,12))
axes[0].plot(df['Price'], label='Price')
axes[0].legend()
axes[1].plot(df['Price'].diff(), label='Diff')
axes[1].legend()
axes[2].plot(df['Price'].pct_change(), label='Pct Diff')
axes[2].legend()

# %%
# time series model: shifting for stationarity.
df.shift(5)
# Out:
#             Price
# Date
# 1987-05-20    NaN
# 1987-05-21    NaN
# 1987-05-22    NaN
# 1987-05-25    NaN
# 1987-05-26    NaN
# ...           ...
# 2022-02-01  89.49
# 2022-02-02  91.22
# 2022-02-03  90.70
# 2022-02-04  91.47
# 2022-02-07  92.35
#
# [8815 rows x 1 columns]

# %%
today = df[['Price']].pct_change()

# %%
today.head()
# Out:
#                Price
# Date
# 1987-05-20       NaN
# 1987-05-21 -0.009662
# 1987-05-22  0.005420
# 1987-05-25  0.002695
# 1987-05-26  0.001613

# %%
yesterday = today[['Price']].shift(2)
yesterday.columns=['Yesterday Price']
yesterday.head()
# Out:
#             Yesterday Price
# Date
# 1987-05-20              NaN
# 1987-05-21              NaN
# 1987-05-22              NaN
# 1987-05-25        -0.009662
# 1987-05-26         0.005420

# %%
today = today.join(yesterday).dropna()
today.head()
# Out:
#                Price  Yesterday Price
# Date
# 1987-05-25  0.002695        -0.009662
# 1987-05-26  0.001613         0.005420
# 1987-05-27 -0.001610         0.002695
# 1987-05-28  0.000000         0.001613
# 1987-05-29 -0.001075        -0.001610

# %%
today['Price'] = (today['Price'] >=0).astype(int)
today.head()
# Out:
#             Price  Yesterday Price
# Date
# 1987-05-25      1        -0.009662
# 1987-05-26      1         0.005420
# 1987-05-27      0         0.002695
# 1987-05-28      1         0.001613
# 1987-05-29      0        -0.001610

# %%
today = today[['Price', 'Yesterday Price']]
today.head()
# Out:
#             Price  Yesterday Price
# Date
# 1987-05-25      1        -0.009662
# 1987-05-26      1         0.005420
# 1987-05-27      0         0.002695
# 1987-05-28      1         0.001613
# 1987-05-29      0        -0.001610

# %%
# def function to plot data
def plot_series(df, col, title='Title', xlab=None, ylab=None, steps=1):
    
    plt.figure(figsize=(17,8))
               
    plt.plot(df[col])
        
    # Generate title and labels.
    plt.title(title, fontsize=25)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    
    # Enlarge tick marks.
    plt.yticks(fontsize=18)
    plt.xticks(df.index[0::steps], fontsize=18);

# %%
# Generate a time plot of our data.
plot_series(df, 'Price', title = "Price of brent Crude", steps=1000)

# %%
# Generate a time plot of our data.
plot_series(df.resample('A').mean(), col='Price', title='Price of brent Crude', steps=4000)

# %%
#Overwrite df.
#df = df['2000':'2020']
#df.head()

# %%
y_train = df['2000': '2007']

# %%
y_test = df['2008']

# %%
y_test.head()
# Out:
#             Price
# Date
# 2008-01-02  97.01
# 2008-01-03  98.45
# 2008-01-04  96.87
# 2008-01-07  94.19
# 2008-01-08  96.37

# %%
df.tail()
# Out:
#             Price
# Date
# 2022-02-01  90.24
# 2022-02-02  91.43
# 2022-02-03  92.99
# 2022-02-04  96.86
# 2022-02-07  97.28

# %% [markdown]
# Observation: we will be using 2000 to

# %% [markdown]
# Modeling

# %%
#more imports
from sklearn.model_selection import train_test_split
import pmdarima as pm
from pmdarima.arima import ADFTest

# %%
# Augmented Dickey-Fuller test 
adf_test = ADFTest(alpha = 0.05) 
adf_test.should_diff(df['Price'])
# Out:
# (0.2792344912779806, True)

# %% [markdown]
# - Since the ADF test

# %%
# Create train-test split.
#y_train, y_test = train_test_split(df['Price'], test_size=.1, shuffle=False)

# %%
# Fit Auto ARIMA
arima_model = pm.AutoARIMA(start_p=0, max_p=4, 
                           d=None,    # find optimum value of d automatically
                           start_q=0, max_q=4,
                           start_P=0, max_P=4,
                           D=None,
                           start_Q=0, max_Q=4,
                           m=12, # For monthly data since the pattern repeats every 12 months
                           seasonal=True,
                           trace=True, # Print values for each fit in the grid search
                           random=True,
                           #random_state=20,
                           n_fits=50
                          )

arima_model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=5546.136, Time=0.36 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=5548.524, Time=0.42 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=5548.614, Time=0.51 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=5546.836, Time=0.05 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=5546.554, Time=0.35 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=5546.644, Time=0.34 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=5548.051, Time=1.37 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=5548.096, Time=0.27 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=5548.098, Time=0.30 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=5542.902, Time=1.36 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=5549.737, Time=1.76 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=5549.818, Time=1.59 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=5551.305, Time=2.63 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=5550.518, Time=0.89 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=5550.523, Time=0.46 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=5548.832, Time=0.31 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=5548.795, Time=0.27 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=5552.509, Time=1.05 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=5543.626, Time=0.70 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[12] intercept
# Total fit time: 15.052 seconds
# AutoARIMA(m=12, max_P=4, max_Q=4, max_p=4, max_q=4, n_fits=50, random=True,
#           start_P=0, start_Q=0, start_p=0, start_q=0, trace=True)

# %%
arima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2046
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -2767.451
# Date:                Tue, 22 Mar 2022   AIC                           5542.902
# Time:                        20:55:01   BIC                           5565.395
# Sample:                             0   HQIC                          5551.152
#                                - 2046
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0680      0.041      1.646      0.100      -0.013       0.149
# ar.L1         -0.9954      0.007   -150.194      0.000      -1.008      -0.982
# ma.L1          0.9887      0.009    112.205      0.000       0.971       1.006
# sigma2         0.8769      0.019     45.993      0.000       0.839       0.914
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):               409.37
# Prob(Q):                              0.78   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.06   Skew:                            -0.08
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
y_pred = arima_model.predict(n_periods = len(y_test))

# Plot data.
plt.figure(figsize=(30,15))

# Plot training data.
plt.plot(y_train, color='blue', label='y_train')

# Plot testing data.
plt.plot(y_test, color='orange', label='y_test')

# Plot predicted test values.
plt.plot(y_test.index, y_pred, color='green', label='y_pred')

plt.title(label = 'ARIMA predictions', fontsize=16)
plt.legend();

# %% [markdown]
# advance time series

# %%
# Plot the Price
plt.figure(figsize=(10,6))
plt.plot(df['Price'])
plt.title(label = 'Monthly Price', fontsize=18)
plt.show();

# %%
y = df['Price']

y_train = y[:'2018']
y_test = y['2019':]

print(y_train.tail())
print(y_test.head())
# Out:
# Date
# 2018-12-19    55.60
# 2018-12-20    52.84
# 2018-12-21    51.93
# 2018-12-27    51.49
# 2018-12-28    50.57
# Name: Price, dtype: float64
# Date
# 2019-01-02    54.06
# 2019-01-03    53.23
# 2019-01-04    55.64
# 2019-01-07    57.10
# 2019-01-08    56.91
# Name: Price, dtype: float64

# %%
# Fit Auto ARIMA
arima_model = pm.AutoARIMA(start_p=0, max_p=10, 
                           d=None,    # find optimum value of d automatically
                           start_q=0, max_q=10,
                           start_P=0, max_P=10,
                           D=None,
                           start_Q=0, max_Q=10,
                           m=12, # For monthly data since the pattern repeats every 12 months
                           seasonal=True,
                           trace=True, # Print values for each fit in the grid search
                           random=True,
                           random_state=20,
                           n_fits=50
                          )

arima_model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=23809.303, Time=0.22 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=23805.316, Time=1.41 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=23805.246, Time=1.71 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=23807.415, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=23803.298, Time=0.83 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=23805.243, Time=1.61 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=7.68 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=23805.213, Time=1.22 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=23805.168, Time=1.02 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=23803.375, Time=0.64 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=23807.265, Time=2.03 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=23801.403, Time=0.33 sec
#  ARIMA(0,1,1)(1,0,0)[12]             : AIC=23803.348, Time=0.72 sec
#  ARIMA(0,1,1)(0,0,1)[12]             : AIC=23803.352, Time=0.74 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=inf, Time=4.61 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=23803.318, Time=0.51 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=23803.274, Time=0.38 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=23801.480, Time=0.23 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=23805.369, Time=0.61 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[12]
# Total fit time: 26.728 seconds
# AutoARIMA(m=12, max_P=10, max_Q=10, max_p=10, max_q=10, n_fits=50, random=True,
#           random_state=20, start_P=0, start_Q=0, start_p=0, start_q=0,
#           trace=True)

# %%
# Create an helper function to help make predictions and plot the results
def plot_forecast(y_train, y_test, arima_model, X_test=None):
    # Generate len(y_test) number of predictions
    y_pred = arima_model.predict(n_periods = len(y_test), X=X_test)

    # Plot data.
    plt.figure(figsize=(10,6))

    # Plot training data.
    plt.plot(y_train, color='blue', label='y_train')

    # Plot testing data.
    plt.plot(y_test, color='orange', label='y_test')

    # Plot predicted test values.
    plt.plot(y_test.index, y_pred, color='green', label='y_pred')
    
    # Find the MAPE of the predictions
    # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_percentage_error.html
    mape = mean_absolute_percentage_error(y_test, y_pred)

    plt.title(label = f'Price Predictions\n MAPE: {mape:.2f}', fontsize=16)
    plt.legend();

# %%
plot_forecast(y_train, y_test, arima_model)

# %%
#SARIMA
from statsmodels.graphics.tsaplots import plot_acf

# %%
# Generate autocorrelation plot on training data.
plot_acf(y_train.diff().dropna());

# %%
# Fit Auto ARIMA
arima_model = pm.AutoARIMA(start_p=0, max_p=10, 
                           d=None,    # find optimum value of d automatically
                           start_q=0, max_q=10,
                           start_P=0, max_P=10,
                           D=None,    # find optimum value of D automatically
                           start_Q=0, max_Q=50,
                           m=3, # Since the peak occurs every 3 months!
                           seasonal=True,
                           trace=True, # Print values for each fit in the grid search
                           random=True,
                           random_state=20,
                           n_fits=50
                          )

arima_model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[3] intercept   : AIC=23809.303, Time=0.20 sec
#  ARIMA(1,1,0)(1,0,0)[3] intercept   : AIC=23805.032, Time=1.01 sec
#  ARIMA(0,1,1)(0,0,1)[3] intercept   : AIC=23804.949, Time=1.10 sec
#  ARIMA(0,1,0)(0,0,0)[3]             : AIC=23807.415, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[3] intercept   : AIC=23803.298, Time=0.78 sec
#  ARIMA(0,1,1)(1,0,0)[3] intercept   : AIC=23804.957, Time=1.03 sec
#  ARIMA(0,1,1)(1,0,1)[3] intercept   : AIC=23806.818, Time=3.61 sec
#  ARIMA(1,1,1)(0,0,0)[3] intercept   : AIC=23805.213, Time=1.20 sec
#  ARIMA(0,1,2)(0,0,0)[3] intercept   : AIC=23805.168, Time=0.99 sec
#  ARIMA(1,1,0)(0,0,0)[3] intercept   : AIC=23803.375, Time=0.63 sec
#  ARIMA(1,1,2)(0,0,0)[3] intercept   : AIC=23807.265, Time=1.90 sec
#  ARIMA(0,1,1)(0,0,0)[3]             : AIC=23801.403, Time=0.34 sec
#  ARIMA(0,1,1)(1,0,0)[3]             : AIC=23803.064, Time=0.46 sec
#  ARIMA(0,1,1)(0,0,1)[3]             : AIC=23803.055, Time=0.51 sec
#  ARIMA(0,1,1)(1,0,1)[3]             : AIC=23804.925, Time=1.58 sec
#  ARIMA(1,1,1)(0,0,0)[3]             : AIC=23803.318, Time=0.48 sec
#  ARIMA(0,1,2)(0,0,0)[3]             : AIC=23803.274, Time=0.39 sec
#  ARIMA(1,1,0)(0,0,0)[3]             : AIC=23801.480, Time=0.24 sec
#  ARIMA(1,1,2)(0,0,0)[3]             : AIC=23805.369, Time=0.66 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[3]
# Total fit time: 17.286 seconds
# AutoARIMA(m=3, max_P=10, max_Q=50, max_p=10, max_q=10, n_fits=50, random=True,
#           random_state=20, start_P=0, start_Q=0, start_p=0, start_q=0,
#           trace=True)

# %%
# Our best model is ARIMA(p=2,d=0,q=0)(P=0,D=1,Q=5)[S=3]
plot_forecast(y_train, y_test, arima_model)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=20,10
from keras.models import Sequential
from keras.layers import LSTM,Dropout,Dense
from sklearn.preprocessing import MinMaxScaler

# %%
import tensorflow as tf
tf.version.VERSION
# Out:
# '2.8.0'

# %%
plt.figure(figsize=(16,8))
plt.plot(df["Price"],label='Price history')

# %%
data.reset_index(inplace= True)
data.head()
# Out:
#         Date  Price
# 0 1987-05-20  18.63
# 1 1987-05-21  18.45
# 2 1987-05-22  18.55
# 3 1987-05-25  18.60
# 4 1987-05-26  18.63

# %%
data.drop(columns=['index'],inplace=True)

# %%
data.head()
# Out:
#         Date  Price
# 0 1987-05-20  18.63
# 1 1987-05-21  18.45
# 2 1987-05-22  18.55
# 3 1987-05-25  18.60
# 4 1987-05-26  18.63

# %%
new_dataset=data.copy()

# %%
new_dataset.head()
# Out:
#             Price
# Date
# 1987-05-20  18.63
# 1987-05-21  18.45
# 1987-05-22  18.55
# 1987-05-25  18.60
# 1987-05-26  18.63

# %%
data=df.sort_index(ascending=True,axis=0)
new_dataset=pd.DataFrame(index=range(0,len(df)),columns=['Date','Price'])
for i in range(0,len(data)):
    new_dataset["Date"][i]=data['Date'][i]
    new_dataset["Price"][i]=data["Price"][i]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-94d02fb151fc> in <module>
#       2 new_dataset=pd.DataFrame(index=range(0,len(df)),columns=['Date','Price'])
#       3 for i in range(0,len(data)):
# ----> 4     new_dataset["Date"][i]=data['Date'][i]
#       5     new_dataset["Price"][i]=data["Price"][i]
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Date'

# %%
data.head()
# Out:
#             Price
# Date
# 1987-05-20  18.63
# 1987-05-21  18.45
# 1987-05-22  18.55
# 1987-05-25  18.60
# 1987-05-26  18.63

# %%
data[data['Date']< '2009-01-01']
# Out:
#            Date  Price
# 0    1987-05-20  18.63
# 1    1987-05-21  18.45
# 2    1987-05-22  18.55
# 3    1987-05-25  18.60
# 4    1987-05-26  18.63
# ...         ...    ...
# 5494 2008-12-24  34.45
# 5495 2008-12-26  33.73
# 5496 2008-12-29  34.16
# 5497 2008-12-30  35.22
# 5498 2008-12-31  35.82
#
# [5499 rows x 2 columns]

# %%
scaler=MinMaxScaler(feature_range=(0,1))
final_dataset=new_dataset.values #y

train_data=final_dataset[0:5245,:]
valid_data=final_dataset[5246:5499,:]

#new_dataset.drop("Date",axis=1,inplace=True)
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(final_dataset)

x_train_data,y_train_data=[],[]

for i in range(60,len(train_data)):
    x_train_data.append(scaled_data[i-60:i,0])
    y_train_data.append(scaled_data[i,0])
    
x_train_data,y_train_data=np.array(x_train_data),np.array(y_train_data)

x_train_data=np.reshape(x_train_data,(x_train_data.shape[0],x_train_data.shape[1],1))

# %%
new_dataset.tail()
# Out:
#             Price
# Date
# 2022-02-01  90.24
# 2022-02-02  91.43
# 2022-02-03  92.99
# 2022-02-04  96.86
# 2022-02-07  97.28

# %%
new_dataset= new_dataset.iloc[:5499,:]

# %%
lstm_model=Sequential()
lstm_model.add(LSTM(units=50,return_sequences=True,input_shape=(x_train_data.shape[1],1)))
lstm_model.add(LSTM(units=50))
lstm_model.add(Dense(1))

inputs_data=new_dataset[len(new_dataset)-len(valid_data)-60:].values
inputs_data=inputs_data.reshape(-1,1)
inputs_data=scaler.transform(inputs_data)

lstm_model.compile(loss='mean_squared_error',optimizer='adam')
lstm_model.fit(x_train_data,y_train_data,epochs=1,batch_size=1,verbose=2)
# Out:
# 5185/5185 - 92s - loss: 2.8783e-04 - 92s/epoch - 18ms/step

# %%
X_test=[]
for i in range(60,inputs_data.shape[0]):
    X_test.append(inputs_data[i-60:i,0])
X_test=np.array(X_test)

X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
predicted_closing_price=lstm_model.predict(X_test)
predicted_closing_price=scaler.inverse_transform(predicted_closing_price)

# %%
lstm_model.save("saved_model.h5")

# %%
train_data=new_dataset[:5245]
valid_data=new_dataset[5246:5499]
valid_data['Predictions']=predicted_closing_price
plt.plot(train_data["Price"])
plt.plot(valid_data[['Price',"Predictions"]])
# Out:
# [<matplotlib.lines.Line2D at 0x2010739fa90>,
#  <matplotlib.lines.Line2D at 0x2010739fb50>]
